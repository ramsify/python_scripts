# %% [markdown]
# # Dataframes contd.
# Lamdbda function
# apply
# map  - will be discussed in the next session
# applymap - will be discussed in the next session

# %%
# Normal function
def cust_print(cntry, cap):
    print('{} is the capital of {}'.format(cap, cntry))
    
cust_print('Germany', 'Berlin')
# Out:
# Berlin is the capital of Germany

# %%
def cust_print(cntry, cap):
    print('{1} is the capital of {0}'.format(cntry, cap))
    
cust_print('Germany', 'Berlin')
# Out:
# Berlin is the capital of Germany

# %% [markdown]
# ### Lambda - anonymous functions - they don't have a proper identity or name
# ### it can have any number of arguments but can have only single expression unlike normal functions

# %%
cntry_cap = lambda tup:   print('{1} is the capital of {0}'.format(*tup))
tup = ('Austria', 'Vienna')
cntry_cap(tup)
# Out:
# Vienna is the capital of Austria

# %% [markdown]
# ### Using lambda in dataframes
# Lambdas are widely used in data transformations and manipulations

# %%
import pandas as pd
import numpy as np

imdb_file = r"C:\Users\ramananb\Downloads\Horror Movies IMDb.csv"
imdb_df = pd.read_csv(imdb_file)
imdb_df
# Out:
#                   Movie Title  Movie Year  Runtime                      Genre  \
# 0                       Alien        1979      117             Horror, Sci-Fi
# 1                      Psycho        1960      109  Horror, Mystery, Thriller
# 2                 The Shining        1980      146              Drama, Horror
# 3                   The Thing        1982      109    Horror, Mystery, Sci-Fi
# 4                     Tumbbad        2018      104     Drama, Fantasy, Horror
# ..                        ...         ...      ...                        ...
# 831                   Troll 2        1990       95    Comedy, Fantasy, Horror
# 832                    Laxmii        2020      141     Action, Comedy, Horror
# 833         Alone in the Dark        2005       96     Action, Horror, Sci-Fi
# 834         House of the Dead        2003       90  Action, Adventure, Horror
# 835  Manos: The Hands of Fate        1966       70                     Horror
#
# ...

# %% [markdown]
# ##### if you a slice a single column from a dataframe -  the resultant would be a series
# ##### if you slice 2 or more columns from a dataframe - the resultant would be a dataframe

# %%
imdb_df['Movie Title']
# Out:
# 0                         Alien
# 1                        Psycho
# 2                   The Shining
# 3                     The Thing
# 4                       Tumbbad
#                  ...
# 831                     Troll 2
# 832                      Laxmii
# 833           Alone in the Dark
# 834           House of the Dead
# 835    Manos: The Hands of Fate
# Name: Movie Title, Length: 836, dtype: object

# %%
type(imdb_df['Movie Title'])
# Out:
# pandas.core.series.Series

# %%
imdb_df['Movie Title'].to_list()
# Out:
# ['Alien',
#  'Psycho',
#  'The Shining',
#  'The Thing',
#  'Tumbbad',
#  'The Exorcist',
#  'Diabolique',
#  "Rosemary's Baby",
#  'What Ever Happened to Baby Jane?',
#  'The Cabinet of Dr. Caligari',
#  'The Blue Elephant',
#  'Shaun of the Dead',
#  'Nosferatu',
#  'Let the Right One In',
#  'King Kong',
#  'Get Out I',
#  'Predator',
#  'I Saw the Devil',
#  'Dawn of the Dead',
#  'Night of the Living Dead',
#  'Freaks',
#  'Frankenstein',
#  'The Innocents',
#  'The Bride of Frankenstein',
#  'Evil Dead II',
#  'Halloween',
#  'Invasion of the Body Snatchers',
#  'American Psycho',
#  'Saw',
#  'Train to Busan',
#  'The Fly',
#  'Zombieland',
#  'The Birds',
#  'The Skin I Live In',
#  'The Others',
#  'What We Do in the Shadows',
#  'Eyes Without a Face',
#  'Vampire Hunter D: Bloodlust',
#  'Repulsion',
#  'One Cut of the Dead',
#  'The Invisible Man',
#  'Peeping Tom',
#  'The Conjuring',
#  'A Quiet Place',
#  '28 Days Later',
# ...

# %%
imdb_df[['Movie Title','Runtime']].to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 imdb_df[['Movie Title','Runtime']].to_list()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_list'

# %%
imdb_df['Gross']
# Out:
# 0      $78.90M
# 1      $32.00M
# 2      $44.02M
# 3      $13.78M
# 4          NaN
#         ...
# 831        NaN
# 832        NaN
# 833     $5.18M
# 834    $10.25M
# 835        NaN
# Name: Gross, Length: 836, dtype: object

# %% [markdown]
# ### In the above column if you observe the values, '$' and 'M' values are redundant
# ### Let's remove them and store it in a new column and convert the dtype = float so we can do statistical or arithmetic operations

# %%
# replacing $ and 'M' values using the str.replace chain method
imdb_df['Gross in million $'] = imdb_df['Gross'].fillna('0').apply(lambda x: x.replace('$','').replace('M',''))

# %%
# converting the column to float
imdb_df['Gross in million $'] = imdb_df['Gross in million $'].astype(float)

# %%
imdb_df['Gross in million $']
# Out:
# 0      78.90
# 1      32.00
# 2      44.02
# 3      13.78
# 4       0.00
#        ...
# 831     0.00
# 832     0.00
# 833     5.18
# 834    10.25
# 835     0.00
# Name: Gross in million $, Length: 836, dtype: float64

# %%
imdb_df
# Out:
#                   Movie Title  Movie Year  Runtime                      Genre  \
# 0                       Alien        1979      117             Horror, Sci-Fi
# 1                      Psycho        1960      109  Horror, Mystery, Thriller
# 2                 The Shining        1980      146              Drama, Horror
# 3                   The Thing        1982      109    Horror, Mystery, Sci-Fi
# 4                     Tumbbad        2018      104     Drama, Fantasy, Horror
# ..                        ...         ...      ...                        ...
# 831                   Troll 2        1990       95    Comedy, Fantasy, Horror
# 832                    Laxmii        2020      141     Action, Comedy, Horror
# 833         Alone in the Dark        2005       96     Action, Horror, Sci-Fi
# 834         House of the Dead        2003       90  Action, Adventure, Horror
# 835  Manos: The Hands of Fate        1966       70                     Horror
#
# ...

# %%
imdb_df['Gross in million $'].sum()
# Out:
# 21882.44

# %%
imdb_df['Gross in million $'].min()
# Out:
# 0.0

# %%
imdb_df['Gross in million $'].max()
# Out:
# 411.33

# %%
# Storing the mean/average value in a variable
avg = imdb_df['Gross in million $'].mean()
avg, type(avg)
# Out:
# (26.175167464114832, numpy.float64)

# %%
imdb_df['Gross in million $']
# Out:
# 0      78.90
# 1      32.00
# 2      44.02
# 3      13.78
# 4       0.00
#        ...
# 831     0.00
# 832     0.00
# 833     5.18
# 834    10.25
# 835     0.00
# Name: Gross in million $, Length: 836, dtype: float64

# %% [markdown]
# ### Creating a new column which has the below logic:
# 0 - if the 'Gross in million' value is < avg
# 1 - if 'Gross in million' value' is >= avg

# %%
imdb_df['Movie Category based on Avg Gross'] = imdb_df['Gross in million $'].apply(lambda x: 0 if(x<avg) else 1)

# %%
imdb_df
# Out:
#                   Movie Title  Movie Year  Runtime                      Genre  \
# 0                       Alien        1979      117             Horror, Sci-Fi
# 1                      Psycho        1960      109  Horror, Mystery, Thriller
# 2                 The Shining        1980      146              Drama, Horror
# 3                   The Thing        1982      109    Horror, Mystery, Sci-Fi
# 4                     Tumbbad        2018      104     Drama, Fantasy, Horror
# ..                        ...         ...      ...                        ...
# 831                   Troll 2        1990       95    Comedy, Fantasy, Horror
# 832                    Laxmii        2020      141     Action, Comedy, Horror
# 833         Alone in the Dark        2005       96     Action, Horror, Sci-Fi
# 834         House of the Dead        2003       90  Action, Adventure, Horror
# 835  Manos: The Hands of Fate        1966       70                     Horror
#
# ...
