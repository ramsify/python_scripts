# %% [markdown]
# # API Requests and json flattening

# %%
# SOAP - Simple Object Access protocol  (file type: XML more secured that REST)
# REST -  Representational State Transfer (file type: mostly json, also supports XML, much faster than SOAP)

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\ramananb\appdata\local\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramananb\appdata\local\anaconda3\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ramananb\appdata\local\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramananb\appdata\local\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ramananb\appdata\local\anaconda3\lib\site-packages (from requests) (1.26.14)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### We will be hitting the endpoint url of rapidapi.com
# (an open API that allows limited no. of free hits per month)

# %%
import requests
import json
url = "https://imdb-top-100-movies.p.rapidapi.com/"
headers = {
"X-RapidAPI-Key": "a85d7f29f6msh0221e41e28e2b71p19ab87jsnfab3ce8fa497",
"X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"
}
response = requests.get(url, headers=headers)
print(response.json())
# Out:
# [{'rank': 1, 'title': 'The Shawshank Redemption', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg', 'rating': '9.3', 'id': 'top1', 'year': 1994, 'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg', 'description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 'trailer': 'https://www.youtube.com/embed/NmzuHjWmXOc', 'genre': ['Drama'], 'director': ['Frank Darabont'], 'writers': ['Stephen King (based on the short novel "Rita Hayworth and the Shawshank Redemption" by)', 'Frank Darabont (screenplay by)'], 'imdbid': 'tt0111161'}, {'rank': 2, 'title': 'The Godfather', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg', 'rating': '9.2', 'id': 'top2', 'year': 1972, 'image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR8,0,380,562_.jpg', 'description': 'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.', 'trailer': 'https://www.youtube.com/embed/rqGJyUB1Q3s', 'genre': ['Crime', 'Drama'], 'director': ['Francis Ford Coppola'], 'writers': ['Mario Puzo (screenplay by)', 'Francis Ford Coppola (screenplay by)'], 'imdbid': 'tt0068646'}, {'rank': 3, 'title': 'The Dark Knight', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg', 'rating': '9.0', 'id': 'top3', 'year': 2008, 'image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg', 'description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.', 'trailer': 'https://www.youtube.com/embed/EXeTwQWrcwY', 'genre': ['Action', 'Crime', 'Drama'], 'director': ['Christopher Nolan'], 'writers': ['Jonathan Nolan (screenplay)', 'Christopher Nolan (screenplay)', 'David S. Goyer (story)'], 'imdbid': 'tt0468569'}, {'rank': 4, 'title': 'The Godfather Part II', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg', 'rating': '9.0', 'id': 'top4', 'year': 1974, 'image': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR7,0,380,562_.jpg', 'description': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'trailer': 'https://www.youtube.com/embed/9O1Iy9od7-A', 'genre': ['Crime', 'Drama'], 'director': ['Francis Ford Coppola'], 'writers': ['Francis Ford Coppola (screenplay by)', 'Mario Puzo (screenplay by)'], 'imdbid': 'tt0071562'}, {'rank': 5, 'title': '12 Angry Men', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg', 'rating': '9.0', 'id': 'top5', 'year': 1957, 'image': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,11,380,562_.jpg', 'description': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'trailer': 'https://www.youtube.com/embed/TEN-2uTi2c0', 'genre': ['Crime', 'Drama'], 'director': ['Sidney Lumet'],  ...

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# ### Explore more on the API response status codes

# %%
# assigning the response.json() to a variable
movies_json = response.json()

# %%
type(movies_json)  # it's actually a list of dictionaries
# Out:
# list

# %% [markdown]
# ### json module has 4 main methods for reading, parsing and writing json objects/files/data
#
# ### 1. json.dumps() - method can convert a Python object into a JSON String
# ### also used for formatting or pretty printng a json string

# %%
json_txt = json.dumps(movies_json, sort_keys=True, indent=4)
print(json_txt)
# Out:
# [
#     {
#         "description": "Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.",
#         "director": [
#             "Frank Darabont"
#         ],
#         "genre": [
#             "Drama"
#         ],
#         "id": "top1",
#         "image": "https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg",
#         "imdbid": "tt0111161",
#         "rank": 1,
#         "rating": "9.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Shawshank Redemption",
#         "trailer": "https://www.youtube.com/embed/NmzuHjWmXOc",
#         "writers": [
#             "Stephen King (based on the short novel \"Rita Hayworth and the Shawshank Redemption\" by)",
#             "Frank Darabont (screenplay by)"
#         ],
#         "year": 1994
#     },
#     {
#         "description": "The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.",
#         "director": [
#             "Francis Ford Coppola"
#         ],
#         "genre": [
#             "Crime",
#             "Drama"
#         ],
#         "id": "top2",
#         "image": "https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR8,0,380,562_.jpg",
#         "imdbid": "tt0068646",
#         "rank": 2,
#         "rating": "9.2",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg",
#         "title": "The Godfather",
#         "trailer": "https://www.youtube.com/embed/rqGJyUB1Q3s",
#         "writers": [
#             "Mario Puzo (screenplay by)",
#             "Francis Ford Coppola (screenplay by)"
#         ],
#         "year": 1972
#     },
#     {
#         "description": "When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.",
#         "director": [
#             "Christopher Nolan"
#         ],
#         "genre": [
#             "Action",
#             "Crime",
#             "Drama"
#         ],
#         "id": "top3",
#         "image": "https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0468569",
#         "rank": 3,
#         "rating": "9.0",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#         "title": "The Dark Knight",
#         "trailer": "https://www.youtube.com/embed/EXeTwQWrcwY",
#         "writers": [
#             "Jonathan Nolan (screenplay)",
#             "Christopher Nolan (screenplay)",
#             "David S. Goyer (story)"
#         ],
#         "year": 2008
#     },
#     {
#         "description": "The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.",
#         "director": [
#             "Francis Ford Coppola"
#         ],
#         "genre": [
#             "Crime",
#             "Drama"
#         ],
#         "id": "top4",
#         "image": "https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR7,0,380,562_.jpg",
#         "imdbid": "tt0071562",
#         "rank": 4,
#         "rating": "9.0",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg",
#         "title": "The Godfather Part II",
#         "trailer": "https://www.youtube.com/embed/9O1Iy9od7-A",
#         "writers": [
#             "Francis Ford Coppola (screenplay by)",
#             "Mario Puzo (screenplay by)"
#         ],
#         "year": 1974
#     },
#     {
#         "description": "The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.",
#         "director": [
#             "Sidney Lumet"
#         ],
#         "genre": [
#             "Crime",
#             "Drama"
#         ],
#         "id": "top5",
#         "image": "https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,11,380,562_.jpg",
#         "imdbid": "tt0050083",
#         "rank": 5,
#         "rating": "9.0",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "12 Angry Men",
#         "trailer": "https://www.youtube.com/embed/TEN-2uTi2c0",
#         "writers": [
#             "Reginald Rose (teleplay \"Twelve Angry Men\")"
#         ],
#         "year": 1957
#     },
#     {
#         "description": "In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.",
#         "director": [
#             "Steven Spielberg"
#         ],
#         "genre": [
#             "Biography",
#             "Drama",
#             "History"
#         ],
#         "id": "top6",
#         "image": "https://m.media-amazon.com/images/M/MV5BNDE4OTMxMTctNmRhYy00NWE2LTg3YzItYTk3M2UwOTU5Njg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,4,380,562_.jpg",
#         "imdbid": "tt0108052",
#         "rank": 6,
#         "rating": "9.0",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNDE4OTMxMTctNmRhYy00NWE2LTg3YzItYTk3M2UwOTU5Njg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Schindler's List",
#         "trailer": "https://www.youtube.com/embed/gG22XNhtnoY",
#         "writers": [
#             "Thomas Keneally (book)",
#             "Steven Zaillian (screenplay)"
#         ],
#         "year": 1993
#     },
#     {
#         "description": "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
#         "director": [
#             "Peter Jackson"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Drama"
#         ],
#         "id": "top7",
#         "image": "https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0167260",
#         "rank": 7,
#         "rating": "9.0",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Lord of the Rings: The Return of the King",
#         "trailer": "https://www.youtube.com/embed/y2rYRu8UW8M",
#         "writers": [
#             "J.R.R. Tolkien (novel \"The Return of the King\")",
#             "Fran Walsh (screenplay)",
#             "Philippa Boyens (screenplay)"
#         ],
#         "year": 2003
#     },
#     {
#         "description": "The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.",
#         "director": [
#             "Quentin Tarantino"
#         ],
#         "genre": [
#             "Crime",
#             "Drama"
#         ],
#         "id": "top8",
#         "image": "https://m.media-amazon.com/images/M/MV5BNGNhMDIzZTUtNTBlZi00MTRlLWFjM2ItYzViMjE3YzI5MjljXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR3,0,380,562_.jpg",
#         "imdbid": "tt0110912",
#         "rank": 8,
#         "rating": "8.8",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNGNhMDIzZTUtNTBlZi00MTRlLWFjM2ItYzViMjE3YzI5MjljXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Pulp Fiction",
#         "trailer": "https://www.youtube.com/embed/5ZAhzsi1ybM",
#         "writers": [
#             "Quentin Tarantino (stories by)",
#             "Roger Avary (stories by)"
#         ],
#         "year": 1994
#     },
#     {
#         "description": "A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.",
#         "director": [
#             "Peter Jackson"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Drama"
#         ],
#         "id": "top9",
#         "image": "https://m.media-amazon.com/images/M/MV5BN2EyZjM3NzUtNWUzMi00MTgxLWI0NTctMzY4M2VlOTdjZWRiXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_QL75_UX380_CR0,1,380,562_.jpg",
#         "imdbid": "tt0120737",
#         "rank": 9,
#         "rating": "8.8",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BN2EyZjM3NzUtNWUzMi00MTgxLWI0NTctMzY4M2VlOTdjZWRiXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Lord of the Rings: The Fellowship of the Ring",
#         "trailer": "https://www.youtube.com/embed/_e8QGuG50ro",
#         "writers": [
#             "J.R.R. Tolkien (novel \"The Fellowship of the Ring\")",
#             "Fran Walsh (screenplay)",
#             "Philippa Boyens (screenplay)"
#         ],
#         "year": 2001
#     },
#     {
#         "description": "A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.",
#         "director": [
#             "Sergio Leone"
#         ],
#         "genre": [
#             "Adventure",
#             "Western"
#         ],
#         "id": "top10",
#         "image": "https://m.media-amazon.com/images/M/MV5BNjJlYmNkZGItM2NhYy00MjlmLTk5NmQtNjg1NmM2ODU4OTMwXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,4,380,562_.jpg",
#         "imdbid": "tt0060196",
#         "rank": 10,
#         "rating": "8.8",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNjJlYmNkZGItM2NhYy00MjlmLTk5NmQtNjg1NmM2ODU4OTMwXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "The Good, the Bad and the Ugly",
#         "trailer": "https://www.youtube.com/embed/WCN5JJY_wiA",
#         "writers": [
#             "Luciano Vincenzoni (story)",
#             "Sergio Leone (story)",
#             "Agenore Incrocci (screenplay)"
#         ],
#         "year": 1966
#     },
#     {
#         "description": "The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.",
#         "director": [
#             "Robert Zemeckis"
#         ],
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "id": "top11",
#         "image": "https://m.media-amazon.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UY562_CR4,0,380,562_.jpg",
#         "imdbid": "tt0109830",
#         "rank": 11,
#         "rating": "8.8",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Forrest Gump",
#         "trailer": "https://www.youtube.com/embed/bLvqoHBptjg",
#         "writers": [
#             "Winston Groom (novel)",
#             "Eric Roth (screenplay)"
#         ],
#         "year": 1994
#     },
#     {
#         "description": "An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.",
#         "director": [
#             "David Fincher"
#         ],
#         "genre": [
#             "Drama"
#         ],
#         "id": "top12",
#         "image": "https://m.media-amazon.com/images/M/MV5BNDIzNDU0YzEtYzE5Ni00ZjlkLTk5ZjgtNjM3NWE4YzA3Nzk3XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,1,380,562_.jpg",
#         "imdbid": "tt0137523",
#         "rank": 12,
#         "rating": "8.8",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNDIzNDU0YzEtYzE5Ni00ZjlkLTk5ZjgtNjM3NWE4YzA3Nzk3XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Fight Club",
#         "trailer": "https://www.youtube.com/embed/qtRKdVHc-cE",
#         "writers": [
#             "Chuck Palahniuk (based on the novel by)",
#             "Jim Uhls (screenplay by)"
#         ],
#         "year": 1999
#     },
#     {
#         "description": "A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.",
#         "director": [
#             "Christopher Nolan"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Sci-Fi"
#         ],
#         "id": "top13",
#         "image": "https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt1375666",
#         "rank": 13,
#         "rating": "8.8",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Inception",
#         "trailer": "https://www.youtube.com/embed/YoHD9XEInc0",
#         "writers": [
#             "Christopher Nolan"
#         ],
#         "year": 2010
#     },
#     {
#         "description": "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.",
#         "director": [
#             "Peter Jackson"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Drama"
#         ],
#         "id": "top14",
#         "image": "https://m.media-amazon.com/images/M/MV5BZGMxZTdjZmYtMmE2Ni00ZTdkLWI5NTgtNjlmMjBiNzU2MmI5XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,14,380,562_.jpg",
#         "imdbid": "tt0167261",
#         "rank": 14,
#         "rating": "8.8",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZGMxZTdjZmYtMmE2Ni00ZTdkLWI5NTgtNjlmMjBiNzU2MmI5XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "The Lord of the Rings: The Two Towers",
#         "trailer": "https://www.youtube.com/embed/hYcw5ksV8YQ",
#         "writers": [
#             "J.R.R. Tolkien (novel \"The Two Towers\")",
#             "Fran Walsh (screenplay)",
#             "Philippa Boyens (screenplay)"
#         ],
#         "year": 2002
#     },
#     {
#         "description": "After the Rebels are brutally overpowered by the Empire on the ice planet Hoth, Luke Skywalker begins Jedi training with Yoda, while his friends are pursued across the galaxy by Darth Vader and bounty hunter Boba Fett.",
#         "director": [
#             "Irvin Kershner"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Fantasy"
#         ],
#         "id": "top15",
#         "image": "https://m.media-amazon.com/images/M/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,15,380,562_.jpg",
#         "imdbid": "tt0080684",
#         "rank": 15,
#         "rating": "8.7",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Star Wars: Episode V - The Empire Strikes Back",
#         "trailer": "https://www.youtube.com/embed/JNwNXF9Y6kY",
#         "writers": [
#             "Leigh Brackett (screenplay by)",
#             "Lawrence Kasdan (screenplay by)",
#             "George Lucas (story by)"
#         ],
#         "year": 1980
#     },
#     {
#         "description": "When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.",
#         "director": [
#             "Lana Wachowski",
#             "Lilly Wachowski"
#         ],
#         "genre": [
#             "Action",
#             "Sci-Fi"
#         ],
#         "id": "top16",
#         "image": "https://m.media-amazon.com/images/M/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,4,380,562_.jpg",
#         "imdbid": "tt0133093",
#         "rank": 16,
#         "rating": "8.7",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "The Matrix",
#         "trailer": "https://www.youtube.com/embed/vKQi3bBA1y8",
#         "writers": [
#             "Lilly Wachowski",
#             "Lana Wachowski"
#         ],
#         "year": 1999
#     },
#     {
#         "description": "The story of Henry Hill and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the Italian-American crime syndicate.",
#         "director": [
#             "Martin Scorsese"
#         ],
#         "genre": [
#             "Biography",
#             "Crime",
#             "Drama"
#         ],
#         "id": "top17",
#         "image": "https://m.media-amazon.com/images/M/MV5BY2NkZjEzMDgtN2RjYy00YzM1LWI4ZmQtMjIwYjFjNmI3ZGEwXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,3,380,562_.jpg",
#         "imdbid": "tt0099685",
#         "rank": 17,
#         "rating": "8.7",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BY2NkZjEzMDgtN2RjYy00YzM1LWI4ZmQtMjIwYjFjNmI3ZGEwXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Goodfellas",
#         "trailer": "https://www.youtube.com/embed/2ilzidi_J8Q",
#         "writers": [
#             "Nicholas Pileggi (book \"Wiseguy\")",
#             "Martin Scorsese (screenplay)"
#         ],
#         "year": 1990
#     },
#     {
#         "description": "In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.",
#         "director": [
#             "Milos Forman"
#         ],
#         "genre": [
#             "Drama"
#         ],
#         "id": "top18",
#         "image": "https://m.media-amazon.com/images/M/MV5BZjA0OWVhOTAtYWQxNi00YzNhLWI4ZjYtNjFjZTEyYjJlNDVlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,1,380,562_.jpg",
#         "imdbid": "tt0073486",
#         "rank": 18,
#         "rating": "8.7",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZjA0OWVhOTAtYWQxNi00YzNhLWI4ZjYtNjFjZTEyYjJlNDVlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "One Flew Over the Cuckoo's Nest",
#         "trailer": "https://www.youtube.com/embed/OXrcDonY-B8",
#         "writers": [
#             "Lawrence Hauben (screenplay)",
#             "Bo Goldman (screenplay)",
#             "Ken Kesey (based on the novel by)"
#         ],
#         "year": 1975
#     },
#     {
#         "description": "Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.",
#         "director": [
#             "David Fincher"
#         ],
#         "genre": [
#             "Crime",
#             "Drama",
#             "Mystery"
#         ],
#         "id": "top19",
#         "image": "https://m.media-amazon.com/images/M/MV5BOTUwODM5MTctZjczMi00OTk4LTg3NWUtNmVhMTAzNTNjYjcyXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,16,380,562_.jpg",
#         "imdbid": "tt0114369",
#         "rank": 19,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BOTUwODM5MTctZjczMi00OTk4LTg3NWUtNmVhMTAzNTNjYjcyXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Se7en",
#         "trailer": "https://www.youtube.com/embed/znmZoVkCjpI",
#         "writers": [
#             "Andrew Kevin Walker"
#         ],
#         "year": 1995
#     },
#     {
#         "description": "Farmers from a village exploited by bandits hire a veteran samurai for protection, who gathers six other samurai to join him. As the samurai teach the peasants how to defend themselves, the village is attacked by an army of bandits.",
#         "director": [
#             "Akira Kurosawa"
#         ],
#         "genre": [
#             "Action",
#             "Drama"
#         ],
#         "id": "top20",
#         "image": "https://m.media-amazon.com/images/M/MV5BNWQ3OTM4ZGItMWEwZi00MjI5LWI3YzgtNTYwNWRkNmIzMGI5XkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_QL75_UY562_CR11,0,380,562_.jpg",
#         "imdbid": "tt0047478",
#         "rank": 20,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNWQ3OTM4ZGItMWEwZi00MjI5LWI3YzgtNTYwNWRkNmIzMGI5XkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_UY67_CR1,0,45,67_AL_.jpg",
#         "title": "Seven Samurai",
#         "trailer": "https://www.youtube.com/embed/wJ1TOratCTo",
#         "writers": [
#             "Akira Kurosawa (screenplay by)",
#             "Shinobu Hashimoto (screenplay by)",
#             "Hideo Oguni (screenplay by)"
#         ],
#         "year": 1954
#     },
#     {
#         "description": "An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.",
#         "director": [
#             "Frank Capra"
#         ],
#         "genre": [
#             "Drama",
#             "Family",
#             "Fantasy"
#         ],
#         "id": "top21",
#         "image": "https://m.media-amazon.com/images/M/MV5BZjc4NDZhZWMtNGEzYS00ZWU2LThlM2ItNTA0YzQ0OTExMTE2XkEyXkFqcGdeQXVyNjUwMzI2NzU@._V1_QL75_UY562_CR3,0,380,562_.jpg",
#         "imdbid": "tt0038650",
#         "rank": 21,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZjc4NDZhZWMtNGEzYS00ZWU2LThlM2ItNTA0YzQ0OTExMTE2XkEyXkFqcGdeQXVyNjUwMzI2NzU@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "It's a Wonderful Life",
#         "trailer": "https://www.youtube.com/embed/iLR3gZrU2Xo",
#         "writers": [
#             "Frances Goodrich (screenplay by)",
#             "Albert Hackett (screenplay by)",
#             "Frank Capra (screenplay by)"
#         ],
#         "year": 1946
#     },
#     {
#         "description": "A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.",
#         "director": [
#             "Jonathan Demme"
#         ],
#         "genre": [
#             "Crime",
#             "Drama",
#             "Thriller"
#         ],
#         "id": "top22",
#         "image": "https://m.media-amazon.com/images/M/MV5BNjNhZTk0ZmEtNjJhMi00YzFlLWE1MmEtYzM1M2ZmMGMwMTU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UY562_CR1,0,380,562_.jpg",
#         "imdbid": "tt0102926",
#         "rank": 22,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNjNhZTk0ZmEtNjJhMi00YzFlLWE1MmEtYzM1M2ZmMGMwMTU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Silence of the Lambs",
#         "trailer": "https://www.youtube.com/embed/W6Mm8Sbe__o",
#         "writers": [
#             "Thomas Harris (based on the novel by)",
#             "Ted Tally (screenplay by)"
#         ],
#         "year": 1991
#     },
#     {
#         "description": "In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.",
#         "director": [
#             "Fernando Meirelles",
#             "K\u00e1tia Lund (co-director)"
#         ],
#         "genre": [
#             "Crime",
#             "Drama"
#         ],
#         "id": "top23",
#         "image": "https://m.media-amazon.com/images/M/MV5BOTMwYjc5ZmItYTFjZC00ZGQ3LTlkNTMtMjZiNTZlMWQzNzI5XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,2,380,562_.jpg",
#         "imdbid": "tt0317248",
#         "rank": 23,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BOTMwYjc5ZmItYTFjZC00ZGQ3LTlkNTMtMjZiNTZlMWQzNzI5XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "City of God",
#         "trailer": "https://www.youtube.com/embed/dcUOO4Itgmw",
#         "writers": [
#             "Paulo Lins (novel)",
#             "Br\u00e1ulio Mantovani (screenplay)"
#         ],
#         "year": 2002
#     },
#     {
#         "description": "Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.",
#         "director": [
#             "Steven Spielberg"
#         ],
#         "genre": [
#             "Drama",
#             "War"
#         ],
#         "id": "top24",
#         "image": "https://m.media-amazon.com/images/M/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_QL75_UY562_CR1,0,380,562_.jpg",
#         "imdbid": "tt0120815",
#         "rank": 24,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Saving Private Ryan",
#         "trailer": "https://www.youtube.com/embed/9CiW_DgxCnQ",
#         "writers": [
#             "Robert Rodat"
#         ],
#         "year": 1998
#     },
#     {
#         "description": "When an open-minded Jewish waiter and his son become victims of the Holocaust, he uses a perfect mixture of will, humor, and imagination to protect his son from the dangers around their camp.",
#         "director": [
#             "Roberto Benigni"
#         ],
#         "genre": [
#             "Comedy",
#             "Drama",
#             "Romance"
#         ],
#         "id": "top25",
#         "image": "https://m.media-amazon.com/images/M/MV5BYmJmM2Q4NmMtYThmNC00ZjRlLWEyZmItZTIwOTBlZDQ3NTQ1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,2,380,562_.jpg",
#         "imdbid": "tt0118799",
#         "rank": 25,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYmJmM2Q4NmMtYThmNC00ZjRlLWEyZmItZTIwOTBlZDQ3NTQ1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Life Is Beautiful",
#         "trailer": "https://www.youtube.com/embed/pAYEQP8gx3w",
#         "writers": [
#             "Vincenzo Cerami (story by)",
#             "Roberto Benigni (story by)"
#         ],
#         "year": 1997
#     },
#     {
#         "description": "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.",
#         "director": [
#             "Christopher Nolan"
#         ],
#         "genre": [
#             "Adventure",
#             "Drama",
#             "Sci-Fi"
#         ],
#         "id": "top26",
#         "image": "https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0816692",
#         "rank": 26,
#         "rating": "8.7",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Interstellar",
#         "trailer": "https://www.youtube.com/embed/4T4wxDnTYLg",
#         "writers": [
#             "Jonathan Nolan",
#             "Christopher Nolan"
#         ],
#         "year": 2014
#     },
#     {
#         "description": "The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.",
#         "director": [
#             "Frank Darabont"
#         ],
#         "genre": [
#             "Crime",
#             "Drama",
#             "Fantasy"
#         ],
#         "id": "top27",
#         "image": "https://m.media-amazon.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0120689",
#         "rank": 27,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Green Mile",
#         "trailer": "https://www.youtube.com/embed/Ki4haFrqSrw",
#         "writers": [
#             "Stephen King (novel)",
#             "Frank Darabont (screenplay)"
#         ],
#         "year": 1999
#     },
#     {
#         "description": "Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader.",
#         "director": [
#             "George Lucas"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Fantasy"
#         ],
#         "id": "top28",
#         "image": "https://m.media-amazon.com/images/M/MV5BOTA5NjhiOTAtZWM0ZC00MWNhLThiMzEtZDFkOTk2OTU1ZDJkXkEyXkFqcGdeQXVyMTA4NDI1NTQx._V1_QL75_UX380_CR0,9,380,562_.jpg",
#         "imdbid": "tt0076759",
#         "rank": 28,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BOTA5NjhiOTAtZWM0ZC00MWNhLThiMzEtZDFkOTk2OTU1ZDJkXkEyXkFqcGdeQXVyMTA4NDI1NTQx._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Star Wars: Episode IV - A New Hope",
#         "trailer": "https://www.youtube.com/embed/L-_xHEv0l-w",
#         "writers": [
#             "George Lucas"
#         ],
#         "year": 1977
#     },
#     {
#         "description": "A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten-year-old son John from a more advanced and powerful cyborg.",
#         "director": [
#             "James Cameron"
#         ],
#         "genre": [
#             "Action",
#             "Sci-Fi"
#         ],
#         "id": "top29",
#         "image": "https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,1,380,562_.jpg",
#         "imdbid": "tt0103064",
#         "rank": 29,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Terminator 2: Judgment Day",
#         "trailer": "https://www.youtube.com/embed/CRRlbK5w8AE",
#         "writers": [
#             "James Cameron",
#             "William Wisher"
#         ],
#         "year": 1991
#     },
#     {
#         "description": "Marty McFly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his close friend, the maverick scientist Doc Brown.",
#         "director": [
#             "Robert Zemeckis"
#         ],
#         "genre": [
#             "Adventure",
#             "Comedy",
#             "Sci-Fi"
#         ],
#         "id": "top30",
#         "image": "https://m.media-amazon.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,14,380,562_.jpg",
#         "imdbid": "tt0088763",
#         "rank": 30,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Back to the Future",
#         "trailer": "https://www.youtube.com/embed/qvsgGtivCgs",
#         "writers": [
#             "Robert Zemeckis",
#             "Bob Gale"
#         ],
#         "year": 1985
#     },
#     {
#         "description": "During her family's move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches, and spirits, and where humans are changed into beasts.",
#         "director": [
#             "Hayao Miyazaki"
#         ],
#         "genre": [
#             "Animation",
#             "Adventure",
#             "Family"
#         ],
#         "id": "top31",
#         "image": "https://m.media-amazon.com/images/M/MV5BMjlmZmI5MDctNDE2YS00YWE0LWE5ZWItZDBhYWQ0NTcxNWRhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0245429",
#         "rank": 31,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMjlmZmI5MDctNDE2YS00YWE0LWE5ZWItZDBhYWQ0NTcxNWRhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Spirited Away",
#         "trailer": "https://www.youtube.com/embed/ByXuk9QqQkk",
#         "writers": [
#             "Hayao Miyazaki"
#         ],
#         "year": 2001
#     },
#     {
#         "description": "A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run and checks into a remote motel run by a young man under the domination of his mother.",
#         "director": [
#             "Alfred Hitchcock"
#         ],
#         "genre": [
#             "Horror",
#             "Mystery",
#             "Thriller"
#         ],
#         "id": "top32",
#         "image": "https://m.media-amazon.com/images/M/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,1,380,562_.jpg",
#         "imdbid": "tt0054215",
#         "rank": 32,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Psycho",
#         "trailer": "https://www.youtube.com/embed/DTJQfFQ40lI",
#         "writers": [
#             "Joseph Stefano (screenplay by)",
#             "Robert Bloch (based on the novel by)"
#         ],
#         "year": 1960
#     },
#     {
#         "description": "A Polish Jewish musician struggles to survive the destruction of the Warsaw ghetto of World War II.",
#         "director": [
#             "Roman Polanski"
#         ],
#         "genre": [
#             "Biography",
#             "Drama",
#             "Music"
#         ],
#         "id": "top33",
#         "image": "https://m.media-amazon.com/images/M/MV5BOWRiZDIxZjktMTA1NC00MDQ2LWEzMjUtMTliZmY3NjQ3ODJiXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UY562_CR14,0,380,562_.jpg",
#         "imdbid": "tt0253474",
#         "rank": 33,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BOWRiZDIxZjktMTA1NC00MDQ2LWEzMjUtMTliZmY3NjQ3ODJiXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR2,0,45,67_AL_.jpg",
#         "title": "The Pianist",
#         "trailer": "https://www.youtube.com/embed/BFwGqLa_oAo",
#         "writers": [
#             "Ronald Harwood (screenplay by)",
#             "Wladyslaw Szpilman (based on the book by)"
#         ],
#         "year": 2002
#     },
#     {
#         "description": "Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.",
#         "director": [
#             "Bong Joon Ho"
#         ],
#         "genre": [
#             "Drama",
#             "Thriller"
#         ],
#         "id": "top34",
#         "image": "https://m.media-amazon.com/images/M/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt6751668",
#         "rank": 34,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Parasite",
#         "trailer": "https://www.youtube.com/embed/5xH0HfJHsaY",
#         "writers": [
#             "Bong Joon Ho (story by)",
#             "Han Jin-won (screenplay by)"
#         ],
#         "year": 2019
#     },
#     {
#         "description": "12-year-old Mathilda is reluctantly taken in by L\u00e9on, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his prot\u00e9g\u00e9e and learns the assassin's trade.",
#         "director": [
#             "Luc Besson"
#         ],
#         "genre": [
#             "Action",
#             "Crime",
#             "Drama"
#         ],
#         "id": "top35",
#         "image": "https://m.media-amazon.com/images/M/MV5BOTgyMWQ0ZWUtN2Q2MS00NmY0LWI3OWMtNjFkMzZlNDZjNTk0XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,2,380,562_.jpg",
#         "imdbid": "tt0110413",
#         "rank": 35,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BOTgyMWQ0ZWUtN2Q2MS00NmY0LWI3OWMtNjFkMzZlNDZjNTk0XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "L\u00e9on: The Professional",
#         "trailer": "https://www.youtube.com/embed/jawVxq1Iyl0",
#         "writers": [
#             "Luc Besson"
#         ],
#         "year": 1994
#     },
#     {
#         "description": "Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.",
#         "director": [
#             "Roger Allers",
#             "Rob Minkoff"
#         ],
#         "genre": [
#             "Animation",
#             "Adventure",
#             "Drama"
#         ],
#         "id": "top36",
#         "image": "https://m.media-amazon.com/images/M/MV5BYTYxNGMyZTYtMjE3MS00MzNjLWFjNmYtMDk3N2FmM2JiM2M1XkEyXkFqcGdeQXVyNjY5NDU4NzI@._V1_QL75_UX380_CR0,1,380,562_.jpg",
#         "imdbid": "tt0110357",
#         "rank": 36,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYTYxNGMyZTYtMjE3MS00MzNjLWFjNmYtMDk3N2FmM2JiM2M1XkEyXkFqcGdeQXVyNjY5NDU4NzI@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Lion King",
#         "trailer": "https://www.youtube.com/embed/eHcZlPpNt0Q",
#         "writers": [
#             "Irene Mecchi (screenplay by)",
#             "Jonathan Roberts (screenplay by)",
#             "Linda Woolverton (screenplay by)"
#         ],
#         "year": 1994
#     },
#     {
#         "description": "A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.",
#         "director": [
#             "Ridley Scott"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Drama"
#         ],
#         "id": "top37",
#         "image": "https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0172495",
#         "rank": 37,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Gladiator",
#         "trailer": "https://www.youtube.com/embed/uvbavW31adA",
#         "writers": [
#             "David Franzoni (story)",
#             "John Logan (screenplay)",
#             "William Nicholson (screenplay)"
#         ],
#         "year": 1994
#     },
#     {
#         "description": "A former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did.",
#         "director": [
#             "Tony Kaye"
#         ],
#         "genre": [
#             "Crime",
#             "Drama"
#         ],
#         "id": "top38",
#         "image": "https://m.media-amazon.com/images/M/MV5BZTJhN2FkYWEtMGI0My00YWM4LWI2MjAtM2UwNjY4MTI2ZTQyXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_QL75_UX380_CR0,1,380,562_.jpg",
#         "imdbid": "tt0120586",
#         "rank": 38,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZTJhN2FkYWEtMGI0My00YWM4LWI2MjAtM2UwNjY4MTI2ZTQyXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "American History X",
#         "trailer": "https://www.youtube.com/embed/XfQYHqsiN5g",
#         "writers": [
#             "David McKenna"
#         ],
#         "year": 2000
#     },
#     {
#         "description": "An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.",
#         "director": [
#             "Martin Scorsese"
#         ],
#         "genre": [
#             "Crime",
#             "Drama",
#             "Thriller"
#         ],
#         "id": "top39",
#         "image": "https://m.media-amazon.com/images/M/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_QL75_UY562_CR0,0,380,562_.jpg",
#         "imdbid": "tt0407887",
#         "rank": 39,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Departed",
#         "trailer": "https://www.youtube.com/embed/iojhqm0JTW4",
#         "writers": [
#             "William Monahan (screenplay)",
#             "Alan Mak (2002 screenplay Mou gaan dou)",
#             "Felix Chong (2002 screenplay Mou gaan dou)"
#         ],
#         "year": 1998
#     },
#     {
#         "description": "A sole survivor tells of the twisty events leading up to a horrific gun battle on a boat, which began when five criminals met at a seemingly random police lineup.",
#         "director": [
#             "Bryan Singer"
#         ],
#         "genre": [
#             "Crime",
#             "Drama",
#             "Mystery"
#         ],
#         "id": "top40",
#         "image": "https://m.media-amazon.com/images/M/MV5BYTViNjMyNmUtNDFkNC00ZDRlLThmMDUtZDU2YWE4NGI2ZjVmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,2,380,562_.jpg",
#         "imdbid": "tt0114814",
#         "rank": 40,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYTViNjMyNmUtNDFkNC00ZDRlLThmMDUtZDU2YWE4NGI2ZjVmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "The Usual Suspects",
#         "trailer": "https://www.youtube.com/embed/Q0eCiCinc4E",
#         "writers": [
#             "Christopher McQuarrie"
#         ],
#         "year": 1995
#     },
#     {
#         "description": "After a tragic accident, two stage magicians in 1890s London engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.",
#         "director": [
#             "Christopher Nolan"
#         ],
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Sci-Fi"
#         ],
#         "id": "top41",
#         "image": "https://m.media-amazon.com/images/M/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0482571",
#         "rank": 41,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Prestige",
#         "trailer": "https://www.youtube.com/embed/RLtaA9fFNXU",
#         "writers": [
#             "Jonathan Nolan (screenplay)",
#             "Christopher Nolan (screenplay)",
#             "Christopher Priest (novel)"
#         ],
#         "year": 2006
#     },
#     {
#         "description": "A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.",
#         "director": [
#             "Damien Chazelle"
#         ],
#         "genre": [
#             "Drama",
#             "Music"
#         ],
#         "id": "top42",
#         "image": "https://m.media-amazon.com/images/M/MV5BOTA5NDZlZGUtMjAxOS00YTRkLTkwYmMtYWQ0NWEwZDZiNjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt2582802",
#         "rank": 42,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BOTA5NDZlZGUtMjAxOS00YTRkLTkwYmMtYWQ0NWEwZDZiNjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Whiplash",
#         "trailer": "https://www.youtube.com/embed/7d_jQycdQGo",
#         "writers": [
#             "Damien Chazelle"
#         ],
#         "year": 2014
#     },
#     {
#         "description": "A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive husband escape the Nazis in French Morocco.",
#         "director": [
#             "Michael Curtiz"
#         ],
#         "genre": [
#             "Drama",
#             "Romance",
#             "War"
#         ],
#         "id": "top43",
#         "image": "https://m.media-amazon.com/images/M/MV5BY2IzZGY2YmEtYzljNS00NTM5LTgwMzUtMzM1NjQ4NGI0OTk0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_QL75_UX380_CR0,5,380,562_.jpg",
#         "imdbid": "tt0034583",
#         "rank": 43,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BY2IzZGY2YmEtYzljNS00NTM5LTgwMzUtMzM1NjQ4NGI0OTk0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Casablanca",
#         "trailer": "https://www.youtube.com/embed/BkL9l7qovsE",
#         "writers": [
#             "Julius J. Epstein (screenplay)",
#             "Philip G. Epstein (screenplay)",
#             "Howard Koch (screenplay)"
#         ],
#         "year": 1942
#     },
#     {
#         "description": "After he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.",
#         "director": [
#             "Olivier Nakache",
#             "\u00c9ric Toledano"
#         ],
#         "genre": [
#             "Biography",
#             "Comedy",
#             "Drama"
#         ],
#         "id": "top44",
#         "image": "https://m.media-amazon.com/images/M/MV5BMTYxNDA3MDQwNl5BMl5BanBnXkFtZTcwNTU4Mzc1Nw@@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt1675434",
#         "rank": 44,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMTYxNDA3MDQwNl5BMl5BanBnXkFtZTcwNTU4Mzc1Nw@@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "The Intouchables",
#         "trailer": "https://www.youtube.com/embed/oK5hMNxqsFA",
#         "writers": [
#             "Olivier Nakache",
#             "Philippe Pozzo di Borgo (adapted from his autobiographical tale Le Second Souffle)",
#             "\u00c9ric Toledano"
#         ],
#         "year": 2011
#     },
#     {
#         "description": "When a ronin requesting seppuku at a feudal lord's palace is told of the brutal suicide of another ronin who previously visited, he reveals how their pasts are intertwined - and in doing so challenges the clan's integrity.",
#         "director": [
#             "Masaki Kobayashi"
#         ],
#         "genre": [
#             "Action",
#             "Drama",
#             "Mystery"
#         ],
#         "id": "top45",
#         "image": "https://m.media-amazon.com/images/M/MV5BYjBmYTQ1NjItZWU5MS00YjI0LTg2OTYtYmFkN2JkMmNiNWVkXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_QL75_UY562_CR17,0,380,562_.jpg",
#         "imdbid": "tt0056058",
#         "rank": 45,
#         "rating": "8.6",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYjBmYTQ1NjItZWU5MS00YjI0LTg2OTYtYmFkN2JkMmNiNWVkXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_UY67_CR2,0,45,67_AL_.jpg",
#         "title": "Harakiri",
#         "trailer": "https://www.youtube.com/embed/gfABwM-Ppng",
#         "writers": [
#             "Yasuhiko Takiguchi (novel \"Ibun r\u00f4nin ki\")",
#             "Shinobu Hashimoto (screenplay)"
#         ],
#         "year": 1962
#     },
#     {
#         "description": "A young boy and his little sister struggle to survive in Japan during World War II.",
#         "director": [
#             "Isao Takahata"
#         ],
#         "genre": [
#             "Animation"
#         ],
#         "id": "top46",
#         "image": "https://m.media-amazon.com/images/M/MV5BZmY2NjUzNDQtNTgxNC00M2Q4LTljOWQtMjNjNDBjNWUxNmJlXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_QL75_UX380_CR0,4,380,562_.jpg",
#         "imdbid": "tt0095327",
#         "rank": 46,
#         "rating": "8.5",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZmY2NjUzNDQtNTgxNC00M2Q4LTljOWQtMjNjNDBjNWUxNmJlXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Grave of the Fireflies",
#         "trailer": "https://www.youtube.com/embed/4vPeTSRd580",
#         "writers": [
#             "Akiyuki Nosaka (novel)",
#             "Isao Takahata"
#         ],
#         "year": 1988
#     },
#     {
#         "description": "The Tramp struggles to live in modern industrial society with the help of a young homeless woman.",
#         "director": [
#             "Charles Chaplin"
#         ],
#         "genre": [
#             "Comedy",
#             "Drama",
#             "Romance"
#         ],
#         "id": "top47",
#         "image": "https://m.media-amazon.com/images/M/MV5BYjJiZjMzYzktNjU0NS00OTkxLWEwYzItYzdhYWJjN2QzMTRlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,15,380,562_.jpg",
#         "imdbid": "tt0027977",
#         "rank": 47,
#         "rating": "8.5",
# ...
#         "trailer": "https://www.youtube.com/embed/JcpWXaA2qeg",
#         "writers": [
#             "John Lasseter (story by)",
#             "Andrew Stanton (story by)",
#             "Lee Unkrich (story by)"
#         ],
#         "year": 2010
#     },
#     {
#         "description": "A silent film star falls for a chorus girl just as he and his delusionally jealous screen partner are trying to make the difficult transition to talking pictures in 1920s Hollywood.",
#         "director": [
#             "Stanley Donen",
#             "Gene Kelly"
#         ],
#         "genre": [
#             "Comedy",
#             "Musical",
#             "Romance"
#         ],
#         "id": "top86",
#         "image": "https://m.media-amazon.com/images/M/MV5BZDRjNGViMjQtOThlMi00MTA3LThkYzQtNzJkYjBkMGE0YzE1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_QL75_UY562_CR3,0,380,562_.jpg",
#         "imdbid": "tt0045152",
#         "rank": 86,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZDRjNGViMjQtOThlMi00MTA3LThkYzQtNzJkYjBkMGE0YzE1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Singin' in the Rain",
#         "trailer": "https://www.youtube.com/embed/5_EVHeNEIJY",
#         "writers": [
#             "Betty Comden (story by)",
#             "Adolph Green (story by)"
#         ],
#         "year": 1952
#     },
#     {
#         "description": "Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of the world called them \"idiots\".",
#         "director": [
#             "Rajkumar Hirani"
#         ],
#         "genre": [
#             "Comedy",
#             "Drama"
#         ],
#         "id": "top87",
#         "image": "https://m.media-amazon.com/images/M/MV5BNTkyOGVjMGEtNmQzZi00NzFlLTlhOWQtODYyMDc2ZGJmYzFhXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UY562_CR5,0,380,562_.jpg",
#         "imdbid": "tt1187043",
#         "rank": 87,
#         "rating": "8.4",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BNTkyOGVjMGEtNmQzZi00NzFlLTlhOWQtODYyMDc2ZGJmYzFhXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR1,0,45,67_AL_.jpg",
#         "title": "3 Idiots",
#         "trailer": "https://www.youtube.com/embed/xvszmNXdM4w",
#         "writers": [
#             "Rajkumar Hirani (screenplay)",
#             "Abhijat Joshi (screenplay)",
#             "Vidhu Vinod Chopra (screenplay associate)"
#         ],
#         "year": 2009
#     },
#     {
#         "description": "An executive of a Yokohama shoe company becomes a victim of extortion when his chauffeur's son is kidnapped by mistake and held for ransom.",
#         "director": [
#             "Akira Kurosawa"
#         ],
#         "genre": [
#             "Crime",
#             "Drama",
#             "Mystery"
#         ],
#         "id": "top88",
#         "image": "https://m.media-amazon.com/images/M/MV5BZGQ1NWZlYjctNDJmOS00MmU2LTg1ODItNmZiM2ZkNzJhNDI0XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UY562_CR9,0,380,562_.jpg",
#         "imdbid": "tt0057565",
#         "rank": 88,
#         "rating": "8.4",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZGQ1NWZlYjctNDJmOS00MmU2LTg1ODItNmZiM2ZkNzJhNDI0XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UY67_CR1,0,45,67_AL_.jpg",
#         "title": "High and Low",
#         "trailer": "https://www.youtube.com/embed/LV3z2Ytxu90",
#         "writers": [
#             "Hideo Oguni (screenplay)",
#             "Ry\u00fbz\u00f4 Kikushima (screenplay)",
#             "Eijir\u00f4 Hisaita (screenplay)"
#         ],
#         "year": 1963
#     },
#     {
#         "description": "After a daring mission to rescue Han Solo from Jabba the Hutt, the Rebels dispatch to Endor to destroy the second Death Star. Meanwhile, Luke struggles to help Darth Vader back from the dark side without falling into the Emperor's trap.",
#         "director": [
#             "Richard Marquand"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Fantasy"
#         ],
#         "id": "top89",
#         "image": "https://m.media-amazon.com/images/M/MV5BOWZlMjFiYzgtMTUzNC00Y2IzLTk1NTMtZmNhMTczNTk0ODk1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_QL75_UX380_CR0,13,380,562_.jpg",
#         "imdbid": "tt0086190",
#         "rank": 89,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BOWZlMjFiYzgtMTUzNC00Y2IzLTk1NTMtZmNhMTczNTk0ODk1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Star Wars: Episode VI - Return of the Jedi",
#         "trailer": "https://www.youtube.com/embed/p4vIFhk621Q",
#         "writers": [
#             "Lawrence Kasdan (screenplay by)",
#             "George Lucas (screenplay by)"
#         ],
#         "year": 1983
#     },
#     {
#         "description": "After uncovering a mysterious artifact buried beneath the Lunar surface, a spacecraft is sent to Jupiter to find its origins - a spacecraft manned by two men and the supercomputer H.A.L. 9000.",
#         "director": [
#             "Stanley Kubrick"
#         ],
#         "genre": [
#             "Adventure",
#             "Sci-Fi"
#         ],
#         "id": "top90",
#         "image": "https://m.media-amazon.com/images/M/MV5BMmNlYzRiNDctZWNhMi00MzI4LThkZTctMTUzMmZkMmFmNThmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0062622",
#         "rank": 90,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMmNlYzRiNDctZWNhMi00MzI4LThkZTctMTUzMmZkMmFmNThmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "2001: A Space Odyssey",
#         "trailer": "https://www.youtube.com/embed/UgGCScAV7qU",
#         "writers": [
#             "Stanley Kubrick (screenplay by)",
#             "Arthur C. Clarke (screenplay by)"
#         ],
#         "year": 1968
#     },
#     {
#         "description": "When their relationship turns sour, a couple undergoes a medical procedure to have each other erased from their memories.",
#         "director": [
#             "Michel Gondry"
#         ],
#         "genre": [
#             "Drama",
#             "Romance",
#             "Sci-Fi"
#         ],
#         "id": "top91",
#         "image": "https://m.media-amazon.com/images/M/MV5BMTY4NzcwODg3Nl5BMl5BanBnXkFtZTcwNTEwOTMyMw@@._V1_QL75_UX380_CR0,0,380,562_.jpg",
#         "imdbid": "tt0338013",
#         "rank": 91,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMTY4NzcwODg3Nl5BMl5BanBnXkFtZTcwNTEwOTMyMw@@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Eternal Sunshine of the Spotless Mind",
#         "trailer": "https://www.youtube.com/embed/07-QBnEkgXU",
#         "writers": [
#             "Charlie Kaufman (story)",
#             "Michel Gondry (story)",
#             "Pierre Bismuth (story)"
#         ],
#         "year": 2004
#     },
#     {
#         "description": "While serving a five-year sentence for a violent crime, a 12-year-old boy sues his parents for neglect.",
#         "director": [
#             "Nadine Labaki"
#         ],
#         "genre": [
#             "Drama"
#         ],
#         "id": "top92",
#         "image": "https://m.media-amazon.com/images/M/MV5BY2Y3OWNkMTctYzNjYS00NWVkLTg4OWEtY2YxN2I3NDhlYzE0XkEyXkFqcGdeQXVyMTI3ODAyMzE2._V1_QL75_UY562_CR7,0,380,562_.jpg",
#         "imdbid": "tt8267604",
#         "rank": 92,
#         "rating": "8.4",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BY2Y3OWNkMTctYzNjYS00NWVkLTg4OWEtY2YxN2I3NDhlYzE0XkEyXkFqcGdeQXVyMTI3ODAyMzE2._V1_UY67_CR1,0,45,67_AL_.jpg",
#         "title": "Capernaum",
#         "trailer": "https://www.youtube.com/embed/ULUo0048xZE",
#         "writers": [
#             "Nadine Labaki (screenplay)",
#             "Jihad Hojeily (screenplay)",
#             "Michelle Keserwany (screenplay)"
#         ],
#         "year": 2018
#     },
#     {
#         "description": "When a simple jewelry heist goes horribly wrong, the surviving criminals begin to suspect that one of them is a police informant.",
#         "director": [
#             "Quentin Tarantino"
#         ],
#         "genre": [
#             "Crime",
#             "Thriller"
#         ],
#         "id": "top93",
#         "image": "https://m.media-amazon.com/images/M/MV5BZmExNmEwYWItYmQzOS00YjA5LTk2MjktZjEyZDE1Y2QxNjA1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,2,380,562_.jpg",
#         "imdbid": "tt0105236",
#         "rank": 93,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZmExNmEwYWItYmQzOS00YjA5LTk2MjktZjEyZDE1Y2QxNjA1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Reservoir Dogs",
#         "trailer": "https://www.youtube.com/embed/vayksn4Y93A",
#         "writers": [
#             "Quentin Tarantino (background radio dialogue written by)",
#             "Roger Avary (background radio dialogue written by)"
#         ],
#         "year": 1992
#     },
#     {
#         "description": "A teacher lives a lonely life, all the while struggling over his son's custody. His life slowly gets better as he finds love and receives good news from his son, but his new luck is about to be brutally shattered by an innocent little lie.",
#         "director": [
#             "Thomas Vinterberg"
#         ],
#         "genre": [
#             "Drama"
#         ],
#         "id": "top94",
#         "image": "https://m.media-amazon.com/images/M/MV5BMTg2NDg3ODg4NF5BMl5BanBnXkFtZTcwNzk3NTc3Nw@@._V1_QL75_UY562_CR7,0,380,562_.jpg",
#         "imdbid": "tt2106476",
#         "rank": 94,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BMTg2NDg3ODg4NF5BMl5BanBnXkFtZTcwNzk3NTc3Nw@@._V1_UY67_CR1,0,45,67_AL_.jpg",
#         "title": "The Hunt",
#         "trailer": "https://www.youtube.com/embed/YsYn6L5fF9Q",
#         "writers": [
#             "Thomas Vinterberg (screenplay)",
#             "Tobias Lindholm (screenplay)"
#         ],
#         "year": 2012
#     },
#     {
#         "description": "Following the death of publishing tycoon Charles Foster Kane, reporters scramble to uncover the meaning of his final utterance: 'Rosebud.'",
#         "director": [
#             "Orson Welles"
#         ],
#         "genre": [
#             "Drama",
#             "Mystery"
#         ],
#         "id": "top95",
#         "image": "https://m.media-amazon.com/images/M/MV5BYjBiOTYxZWItMzdiZi00NjlkLWIzZTYtYmFhZjhiMTljOTdkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,4,380,562_.jpg",
#         "imdbid": "tt0033467",
#         "rank": 95,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYjBiOTYxZWItMzdiZi00NjlkLWIzZTYtYmFhZjhiMTljOTdkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Citizen Kane",
#         "trailer": "https://www.youtube.com/embed/8dxh3lwdOFw",
#         "writers": [
#             "Herman J. Mankiewicz (original screen play)",
#             "Orson Welles (original screen play)",
#             "John Houseman (contributing writer)"
#         ],
#         "year": 1941
#     },
#     {
#         "description": "The story of T.E. Lawrence, the English officer who successfully united and led the diverse, often warring, Arab tribes during World War I in order to fight the Turks.",
#         "director": [
#             "David Lean"
#         ],
#         "genre": [
#             "Adventure",
#             "Biography",
#             "Drama"
#         ],
#         "id": "top96",
#         "image": "https://m.media-amazon.com/images/M/MV5BYWY5ZjhjNGYtZmI2Ny00ODM0LWFkNzgtZmI1YzA2N2MxMzA0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_QL75_UY562_CR5,0,380,562_.jpg",
#         "imdbid": "tt0056172",
#         "rank": 96,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYWY5ZjhjNGYtZmI2Ny00ODM0LWFkNzgtZmI1YzA2N2MxMzA0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY67_CR0,0,45,67_AL_.jpg",
#         "title": "Lawrence of Arabia",
#         "trailer": "https://www.youtube.com/embed/vOlRhGEhG7k",
#         "writers": [
#             "Robert Bolt (screenplay by)",
#             "Michael Wilson (screenplay by)"
#         ],
#         "year": 1962
#     },
#     {
#         "description": "When the police in a German city are unable to catch a child-murderer, other criminals join in the manhunt.",
#         "director": [
#             "Fritz Lang"
#         ],
#         "genre": [
#             "Crime",
#             "Mystery",
#             "Thriller"
#         ],
#         "id": "top97",
#         "image": "https://m.media-amazon.com/images/M/MV5BODA4ODk3OTEzMF5BMl5BanBnXkFtZTgwMTQ2ODMwMzE@._V1_QL75_UX380_CR0,4,380,562_.jpg",
#         "imdbid": "tt0022100",
#         "rank": 97,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BODA4ODk3OTEzMF5BMl5BanBnXkFtZTgwMTQ2ODMwMzE@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "M",
#         "trailer": "https://www.youtube.com/embed/nsVproWjN6c",
#         "writers": [
#             "Thea von Harbou (script)",
#             "Fritz Lang (script)",
#             "Egon Jacobsohn (article)"
#         ],
#         "year": 1931
#     },
#     {
#         "description": "After finding an old rifle, a young boy joins the Soviet resistance movement against ruthless German forces and experiences the horrors of World War II.",
#         "director": [
#             "Elem Klimov"
#         ],
#         "genre": [
#             "Drama",
#             "Thriller",
#             "War"
#         ],
#         "id": "top98",
#         "image": "https://m.media-amazon.com/images/M/MV5BODM4Njg0NTAtYjI5Ny00ZjAxLTkwNmItZTMxMWU5M2U3M2RjXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,10,380,562_.jpg",
#         "imdbid": "tt0091251",
#         "rank": 98,
#         "rating": "8.4",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BODM4Njg0NTAtYjI5Ny00ZjAxLTkwNmItZTMxMWU5M2U3M2RjXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX100_CR0,3,100,148_.jpg",
#         "title": "Come and See",
#         "trailer": "https://www.youtube.com/embed/UHaSQU-4wss",
#         "writers": [
#             "Ales Adamovich (story)",
#             "Elem Klimov (screenplay)"
#         ],
#         "year": 1985
#     },
#     {
#         "description": "A New York City advertising executive goes on the run after being mistaken for a government agent by a group of foreign spies, and falls for a woman whose loyalties he begins to doubt.",
#         "director": [
#             "Alfred Hitchcock"
#         ],
#         "genre": [
#             "Action",
#             "Adventure",
#             "Mystery"
#         ],
#         "id": "top99",
#         "image": "https://m.media-amazon.com/images/M/MV5BZDA3NDExMTUtMDlhOC00MmQ5LWExZGUtYmI1NGVlZWI4OWNiXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,5,380,562_.jpg",
#         "imdbid": "tt0053125",
#         "rank": 99,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BZDA3NDExMTUtMDlhOC00MmQ5LWExZGUtYmI1NGVlZWI4OWNiXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "North by Northwest",
#         "trailer": "https://www.youtube.com/embed/Fx0QuZJVTFE",
#         "writers": [
#             "Ernest Lehman"
#         ],
#         "year": 1959
#     },
#     {
#         "description": "A former San Francisco police detective juggles wrestling with his personal demons and becoming obsessed with the hauntingly beautiful woman he has been hired to trail, who may be deeply disturbed.",
#         "director": [
#             "Alfred Hitchcock"
#         ],
#         "genre": [
#             "Mystery",
#             "Romance",
#             "Thriller"
#         ],
#         "id": "top100",
#         "image": "https://m.media-amazon.com/images/M/MV5BYTE4ODEwZDUtNDFjOC00NjAxLWEzYTQtYTI1NGVmZmFlNjdiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,13,380,562_.jpg",
#         "imdbid": "tt0052357",
#         "rank": 100,
#         "rating": "8.3",
#         "thumbnail": "https://m.media-amazon.com/images/M/MV5BYTE4ODEwZDUtNDFjOC00NjAxLWEzYTQtYTI1NGVmZmFlNjdiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg",
#         "title": "Vertigo",
#         "trailer": "https://www.youtube.com/embed/Z5jvQwwHQNY",
#         "writers": [
#             "Alec Coppel (screenplay by)",
#             "Samuel A. Taylor (screenplay by)",
#             "Pierre Boileau (based on the novel \"D'Entre Les Morts\" by)"
#         ],
#         "year": 1958
#     }
# ]

# %% [markdown]
# ### 2. json.dump() - method used to write a json str to a json file

# %%
import os
with open('{}/movies.json'.format(os.getcwd()),'w') as outfile:
    json.dump(json_txt, outfile)
    outfile.close()

# %%
os.chdir(r"C:\Users\ramananb\Documents\Python Scripts")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ramananb\\Documents\\Python Scripts'

# %%
"""
We are using the below method because since it is a list of dictionaries the json.dump() method keeps inserting 
carriage return \n characters making the json file difficult to read 
and messing up with the pretty print (not the actual data though)
"""
import os
with open('{}/movies.json'.format(os.getcwd()),'w') as outfile:
    outfile.write(json_txt)
    outfile.close()

# %% [markdown]
# ### 3. json.loads() - method can be used to parse a valid json string and convert it to a  json object

# %%
y = json.loads(json_txt)
y
# Out:
# [{'description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#   'director': ['Frank Darabont'],
#   'genre': ['Drama'],
#   'id': 'top1',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg',
#   'imdbid': 'tt0111161',
#   'rank': 1,
#   'rating': '9.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Shawshank Redemption',
#   'trailer': 'https://www.youtube.com/embed/NmzuHjWmXOc',
#   'writers': ['Stephen King (based on the short novel "Rita Hayworth and the Shawshank Redemption" by)',
#    'Frank Darabont (screenplay by)'],
#   'year': 1994},
#  {'description': 'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.',
#   'director': ['Francis Ford Coppola'],
#   'genre': ['Crime', 'Drama'],
#   'id': 'top2',
#   'image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR8,0,380,562_.jpg',
#   'imdbid': 'tt0068646',
#   'rank': 2,
#   'rating': '9.2',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg',
#   'title': 'The Godfather',
#   'trailer': 'https://www.youtube.com/embed/rqGJyUB1Q3s',
#   'writers': ['Mario Puzo (screenplay by)',
#    'Francis Ford Coppola (screenplay by)'],
#   'year': 1972},
#  {'description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
#   'director': ['Christopher Nolan'],
#   'genre': ['Action', 'Crime', 'Drama'],
#   'id': 'top3',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0468569',
#   'rank': 3,
#   'rating': '9.0',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'title': 'The Dark Knight',
#   'trailer': 'https://www.youtube.com/embed/EXeTwQWrcwY',
#   'writers': ['Jonathan Nolan (screenplay)',
#    'Christopher Nolan (screenplay)',
#    'David S. Goyer (story)'],
#   'year': 2008},
#  {'description': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.',
#   'director': ['Francis Ford Coppola'],
#   'genre': ['Crime', 'Drama'],
#   'id': 'top4',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR7,0,380,562_.jpg',
#   'imdbid': 'tt0071562',
#   'rank': 4,
#   'rating': '9.0',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg',
#   'title': 'The Godfather Part II',
#   'trailer': 'https://www.youtube.com/embed/9O1Iy9od7-A',
#   'writers': ['Francis Ford Coppola (screenplay by)',
#    'Mario Puzo (screenplay by)'],
#   'year': 1974},
#  {'description': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.',
#   'director': ['Sidney Lumet'],
#   'genre': ['Crime', 'Drama'],
#   'id': 'top5',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,11,380,562_.jpg',
#   'imdbid': 'tt0050083',
#   'rank': 5,
#   'rating': '9.0',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': '12 Angry Men',
#   'trailer': 'https://www.youtube.com/embed/TEN-2uTi2c0',
#   'writers': ['Reginald Rose (teleplay "Twelve Angry Men")'],
#   'year': 1957},
#  {'description': 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.',
#   'director': ['Steven Spielberg'],
#   'genre': ['Biography', 'Drama', 'History'],
#   'id': 'top6',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNDE4OTMxMTctNmRhYy00NWE2LTg3YzItYTk3M2UwOTU5Njg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,4,380,562_.jpg',
#   'imdbid': 'tt0108052',
#   'rank': 6,
#   'rating': '9.0',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNDE4OTMxMTctNmRhYy00NWE2LTg3YzItYTk3M2UwOTU5Njg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': "Schindler's List",
#   'trailer': 'https://www.youtube.com/embed/gG22XNhtnoY',
#   'writers': ['Thomas Keneally (book)', 'Steven Zaillian (screenplay)'],
#   'year': 1993},
#  {'description': "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
#   'director': ['Peter Jackson'],
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'id': 'top7',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0167260',
#   'rank': 7,
#   'rating': '9.0',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Lord of the Rings: The Return of the King',
#   'trailer': 'https://www.youtube.com/embed/y2rYRu8UW8M',
#   'writers': ['J.R.R. Tolkien (novel "The Return of the King")',
#    'Fran Walsh (screenplay)',
#    'Philippa Boyens (screenplay)'],
#   'year': 2003},
#  {'description': 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.',
#   'director': ['Quentin Tarantino'],
#   'genre': ['Crime', 'Drama'],
#   'id': 'top8',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNGNhMDIzZTUtNTBlZi00MTRlLWFjM2ItYzViMjE3YzI5MjljXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR3,0,380,562_.jpg',
#   'imdbid': 'tt0110912',
#   'rank': 8,
#   'rating': '8.8',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNGNhMDIzZTUtNTBlZi00MTRlLWFjM2ItYzViMjE3YzI5MjljXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Pulp Fiction',
#   'trailer': 'https://www.youtube.com/embed/5ZAhzsi1ybM',
#   'writers': ['Quentin Tarantino (stories by)', 'Roger Avary (stories by)'],
#   'year': 1994},
#  {'description': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.',
#   'director': ['Peter Jackson'],
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'id': 'top9',
#   'image': 'https://m.media-amazon.com/images/M/MV5BN2EyZjM3NzUtNWUzMi00MTgxLWI0NTctMzY4M2VlOTdjZWRiXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_QL75_UX380_CR0,1,380,562_.jpg',
#   'imdbid': 'tt0120737',
#   'rank': 9,
#   'rating': '8.8',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BN2EyZjM3NzUtNWUzMi00MTgxLWI0NTctMzY4M2VlOTdjZWRiXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'trailer': 'https://www.youtube.com/embed/_e8QGuG50ro',
#   'writers': ['J.R.R. Tolkien (novel "The Fellowship of the Ring")',
#    'Fran Walsh (screenplay)',
#    'Philippa Boyens (screenplay)'],
#   'year': 2001},
#  {'description': 'A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.',
#   'director': ['Sergio Leone'],
#   'genre': ['Adventure', 'Western'],
#   'id': 'top10',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNjJlYmNkZGItM2NhYy00MjlmLTk5NmQtNjg1NmM2ODU4OTMwXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,4,380,562_.jpg',
#   'imdbid': 'tt0060196',
#   'rank': 10,
#   'rating': '8.8',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNjJlYmNkZGItM2NhYy00MjlmLTk5NmQtNjg1NmM2ODU4OTMwXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'The Good, the Bad and the Ugly',
#   'trailer': 'https://www.youtube.com/embed/WCN5JJY_wiA',
#   'writers': ['Luciano Vincenzoni (story)',
#    'Sergio Leone (story)',
#    'Agenore Incrocci (screenplay)'],
#   'year': 1966},
#  {'description': 'The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.',
#   'director': ['Robert Zemeckis'],
#   'genre': ['Drama', 'Romance'],
#   'id': 'top11',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UY562_CR4,0,380,562_.jpg',
#   'imdbid': 'tt0109830',
#   'rank': 11,
#   'rating': '8.8',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Forrest Gump',
#   'trailer': 'https://www.youtube.com/embed/bLvqoHBptjg',
#   'writers': ['Winston Groom (novel)', 'Eric Roth (screenplay)'],
#   'year': 1994},
#  {'description': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.',
#   'director': ['David Fincher'],
#   'genre': ['Drama'],
#   'id': 'top12',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNDIzNDU0YzEtYzE5Ni00ZjlkLTk5ZjgtNjM3NWE4YzA3Nzk3XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,1,380,562_.jpg',
#   'imdbid': 'tt0137523',
#   'rank': 12,
#   'rating': '8.8',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNDIzNDU0YzEtYzE5Ni00ZjlkLTk5ZjgtNjM3NWE4YzA3Nzk3XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Fight Club',
#   'trailer': 'https://www.youtube.com/embed/qtRKdVHc-cE',
#   'writers': ['Chuck Palahniuk (based on the novel by)',
#    'Jim Uhls (screenplay by)'],
#   'year': 1999},
#  {'description': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.',
#   'director': ['Christopher Nolan'],
#   'genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'id': 'top13',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt1375666',
#   'rank': 13,
#   'rating': '8.8',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Inception',
#   'trailer': 'https://www.youtube.com/embed/YoHD9XEInc0',
#   'writers': ['Christopher Nolan'],
#   'year': 2010},
#  {'description': "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.",
#   'director': ['Peter Jackson'],
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'id': 'top14',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZGMxZTdjZmYtMmE2Ni00ZTdkLWI5NTgtNjlmMjBiNzU2MmI5XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,14,380,562_.jpg',
#   'imdbid': 'tt0167261',
#   'rank': 14,
#   'rating': '8.8',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZGMxZTdjZmYtMmE2Ni00ZTdkLWI5NTgtNjlmMjBiNzU2MmI5XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'The Lord of the Rings: The Two Towers',
#   'trailer': 'https://www.youtube.com/embed/hYcw5ksV8YQ',
#   'writers': ['J.R.R. Tolkien (novel "The Two Towers")',
#    'Fran Walsh (screenplay)',
#    'Philippa Boyens (screenplay)'],
#   'year': 2002},
#  {'description': 'After the Rebels are brutally overpowered by the Empire on the ice planet Hoth, Luke Skywalker begins Jedi training with Yoda, while his friends are pursued across the galaxy by Darth Vader and bounty hunter Boba Fett.',
#   'director': ['Irvin Kershner'],
#   'genre': ['Action', 'Adventure', 'Fantasy'],
#   'id': 'top15',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,15,380,562_.jpg',
#   'imdbid': 'tt0080684',
#   'rank': 15,
#   'rating': '8.7',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'trailer': 'https://www.youtube.com/embed/JNwNXF9Y6kY',
#   'writers': ['Leigh Brackett (screenplay by)',
#    'Lawrence Kasdan (screenplay by)',
#    'George Lucas (story by)'],
#   'year': 1980},
#  {'description': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.',
#   'director': ['Lana Wachowski', 'Lilly Wachowski'],
#   'genre': ['Action', 'Sci-Fi'],
#   'id': 'top16',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,4,380,562_.jpg',
#   'imdbid': 'tt0133093',
#   'rank': 16,
#   'rating': '8.7',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'The Matrix',
#   'trailer': 'https://www.youtube.com/embed/vKQi3bBA1y8',
#   'writers': ['Lilly Wachowski', 'Lana Wachowski'],
#   'year': 1999},
#  {'description': 'The story of Henry Hill and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the Italian-American crime syndicate.',
#   'director': ['Martin Scorsese'],
#   'genre': ['Biography', 'Crime', 'Drama'],
#   'id': 'top17',
#   'image': 'https://m.media-amazon.com/images/M/MV5BY2NkZjEzMDgtN2RjYy00YzM1LWI4ZmQtMjIwYjFjNmI3ZGEwXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,3,380,562_.jpg',
#   'imdbid': 'tt0099685',
#   'rank': 17,
#   'rating': '8.7',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BY2NkZjEzMDgtN2RjYy00YzM1LWI4ZmQtMjIwYjFjNmI3ZGEwXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Goodfellas',
#   'trailer': 'https://www.youtube.com/embed/2ilzidi_J8Q',
#   'writers': ['Nicholas Pileggi (book "Wiseguy")',
#    'Martin Scorsese (screenplay)'],
#   'year': 1990},
#  {'description': 'In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.',
#   'director': ['Milos Forman'],
#   'genre': ['Drama'],
#   'id': 'top18',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZjA0OWVhOTAtYWQxNi00YzNhLWI4ZjYtNjFjZTEyYjJlNDVlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,1,380,562_.jpg',
#   'imdbid': 'tt0073486',
#   'rank': 18,
#   'rating': '8.7',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZjA0OWVhOTAtYWQxNi00YzNhLWI4ZjYtNjFjZTEyYjJlNDVlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': "One Flew Over the Cuckoo's Nest",
#   'trailer': 'https://www.youtube.com/embed/OXrcDonY-B8',
#   'writers': ['Lawrence Hauben (screenplay)',
#    'Bo Goldman (screenplay)',
#    'Ken Kesey (based on the novel by)'],
#   'year': 1975},
#  {'description': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.',
#   'director': ['David Fincher'],
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'id': 'top19',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOTUwODM5MTctZjczMi00OTk4LTg3NWUtNmVhMTAzNTNjYjcyXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,16,380,562_.jpg',
#   'imdbid': 'tt0114369',
#   'rank': 19,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOTUwODM5MTctZjczMi00OTk4LTg3NWUtNmVhMTAzNTNjYjcyXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Se7en',
#   'trailer': 'https://www.youtube.com/embed/znmZoVkCjpI',
#   'writers': ['Andrew Kevin Walker'],
#   'year': 1995},
#  {'description': 'Farmers from a village exploited by bandits hire a veteran samurai for protection, who gathers six other samurai to join him. As the samurai teach the peasants how to defend themselves, the village is attacked by an army of bandits.',
#   'director': ['Akira Kurosawa'],
#   'genre': ['Action', 'Drama'],
#   'id': 'top20',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNWQ3OTM4ZGItMWEwZi00MjI5LWI3YzgtNTYwNWRkNmIzMGI5XkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_QL75_UY562_CR11,0,380,562_.jpg',
#   'imdbid': 'tt0047478',
#   'rank': 20,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNWQ3OTM4ZGItMWEwZi00MjI5LWI3YzgtNTYwNWRkNmIzMGI5XkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_UY67_CR1,0,45,67_AL_.jpg',
#   'title': 'Seven Samurai',
#   'trailer': 'https://www.youtube.com/embed/wJ1TOratCTo',
#   'writers': ['Akira Kurosawa (screenplay by)',
#    'Shinobu Hashimoto (screenplay by)',
#    'Hideo Oguni (screenplay by)'],
#   'year': 1954},
#  {'description': 'An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.',
#   'director': ['Frank Capra'],
#   'genre': ['Drama', 'Family', 'Fantasy'],
#   'id': 'top21',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZjc4NDZhZWMtNGEzYS00ZWU2LThlM2ItNTA0YzQ0OTExMTE2XkEyXkFqcGdeQXVyNjUwMzI2NzU@._V1_QL75_UY562_CR3,0,380,562_.jpg',
#   'imdbid': 'tt0038650',
#   'rank': 21,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZjc4NDZhZWMtNGEzYS00ZWU2LThlM2ItNTA0YzQ0OTExMTE2XkEyXkFqcGdeQXVyNjUwMzI2NzU@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': "It's a Wonderful Life",
#   'trailer': 'https://www.youtube.com/embed/iLR3gZrU2Xo',
#   'writers': ['Frances Goodrich (screenplay by)',
#    'Albert Hackett (screenplay by)',
#    'Frank Capra (screenplay by)'],
#   'year': 1946},
#  {'description': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.',
#   'director': ['Jonathan Demme'],
#   'genre': ['Crime', 'Drama', 'Thriller'],
#   'id': 'top22',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNjNhZTk0ZmEtNjJhMi00YzFlLWE1MmEtYzM1M2ZmMGMwMTU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UY562_CR1,0,380,562_.jpg',
#   'imdbid': 'tt0102926',
#   'rank': 22,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNjNhZTk0ZmEtNjJhMi00YzFlLWE1MmEtYzM1M2ZmMGMwMTU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Silence of the Lambs',
#   'trailer': 'https://www.youtube.com/embed/W6Mm8Sbe__o',
#   'writers': ['Thomas Harris (based on the novel by)',
#    'Ted Tally (screenplay by)'],
#   'year': 1991},
#  {'description': "In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.",
#   'director': ['Fernando Meirelles', 'Kátia Lund (co-director)'],
#   'genre': ['Crime', 'Drama'],
#   'id': 'top23',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOTMwYjc5ZmItYTFjZC00ZGQ3LTlkNTMtMjZiNTZlMWQzNzI5XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,2,380,562_.jpg',
#   'imdbid': 'tt0317248',
#   'rank': 23,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOTMwYjc5ZmItYTFjZC00ZGQ3LTlkNTMtMjZiNTZlMWQzNzI5XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'City of God',
#   'trailer': 'https://www.youtube.com/embed/dcUOO4Itgmw',
#   'writers': ['Paulo Lins (novel)', 'Bráulio Mantovani (screenplay)'],
#   'year': 2002},
#  {'description': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.',
#   'director': ['Steven Spielberg'],
#   'genre': ['Drama', 'War'],
#   'id': 'top24',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_QL75_UY562_CR1,0,380,562_.jpg',
#   'imdbid': 'tt0120815',
#   'rank': 24,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Saving Private Ryan',
#   'trailer': 'https://www.youtube.com/embed/9CiW_DgxCnQ',
#   'writers': ['Robert Rodat'],
#   'year': 1998},
#  {'description': 'When an open-minded Jewish waiter and his son become victims of the Holocaust, he uses a perfect mixture of will, humor, and imagination to protect his son from the dangers around their camp.',
#   'director': ['Roberto Benigni'],
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'id': 'top25',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYmJmM2Q4NmMtYThmNC00ZjRlLWEyZmItZTIwOTBlZDQ3NTQ1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,2,380,562_.jpg',
#   'imdbid': 'tt0118799',
#   'rank': 25,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYmJmM2Q4NmMtYThmNC00ZjRlLWEyZmItZTIwOTBlZDQ3NTQ1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Life Is Beautiful',
#   'trailer': 'https://www.youtube.com/embed/pAYEQP8gx3w',
#   'writers': ['Vincenzo Cerami (story by)', 'Roberto Benigni (story by)'],
#   'year': 1997},
#  {'description': "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.",
#   'director': ['Christopher Nolan'],
#   'genre': ['Adventure', 'Drama', 'Sci-Fi'],
#   'id': 'top26',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0816692',
#   'rank': 26,
#   'rating': '8.7',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Interstellar',
#   'trailer': 'https://www.youtube.com/embed/4T4wxDnTYLg',
#   'writers': ['Jonathan Nolan', 'Christopher Nolan'],
#   'year': 2014},
#  {'description': 'The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.',
#   'director': ['Frank Darabont'],
#   'genre': ['Crime', 'Drama', 'Fantasy'],
#   'id': 'top27',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0120689',
#   'rank': 27,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Green Mile',
#   'trailer': 'https://www.youtube.com/embed/Ki4haFrqSrw',
#   'writers': ['Stephen King (novel)', 'Frank Darabont (screenplay)'],
#   'year': 1999},
#  {'description': "Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader.",
#   'director': ['George Lucas'],
#   'genre': ['Action', 'Adventure', 'Fantasy'],
#   'id': 'top28',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOTA5NjhiOTAtZWM0ZC00MWNhLThiMzEtZDFkOTk2OTU1ZDJkXkEyXkFqcGdeQXVyMTA4NDI1NTQx._V1_QL75_UX380_CR0,9,380,562_.jpg',
#   'imdbid': 'tt0076759',
#   'rank': 28,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOTA5NjhiOTAtZWM0ZC00MWNhLThiMzEtZDFkOTk2OTU1ZDJkXkEyXkFqcGdeQXVyMTA4NDI1NTQx._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Star Wars: Episode IV - A New Hope',
#   'trailer': 'https://www.youtube.com/embed/L-_xHEv0l-w',
#   'writers': ['George Lucas'],
#   'year': 1977},
#  {'description': 'A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten-year-old son John from a more advanced and powerful cyborg.',
#   'director': ['James Cameron'],
#   'genre': ['Action', 'Sci-Fi'],
#   'id': 'top29',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,1,380,562_.jpg',
#   'imdbid': 'tt0103064',
#   'rank': 29,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Terminator 2: Judgment Day',
#   'trailer': 'https://www.youtube.com/embed/CRRlbK5w8AE',
#   'writers': ['James Cameron', 'William Wisher'],
#   'year': 1991},
#  {'description': 'Marty McFly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his close friend, the maverick scientist Doc Brown.',
#   'director': ['Robert Zemeckis'],
#   'genre': ['Adventure', 'Comedy', 'Sci-Fi'],
#   'id': 'top30',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,14,380,562_.jpg',
#   'imdbid': 'tt0088763',
#   'rank': 30,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Back to the Future',
#   'trailer': 'https://www.youtube.com/embed/qvsgGtivCgs',
#   'writers': ['Robert Zemeckis', 'Bob Gale'],
#   'year': 1985},
#  {'description': "During her family's move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches, and spirits, and where humans are changed into beasts.",
#   'director': ['Hayao Miyazaki'],
#   'genre': ['Animation', 'Adventure', 'Family'],
#   'id': 'top31',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMjlmZmI5MDctNDE2YS00YWE0LWE5ZWItZDBhYWQ0NTcxNWRhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0245429',
#   'rank': 31,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMjlmZmI5MDctNDE2YS00YWE0LWE5ZWItZDBhYWQ0NTcxNWRhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Spirited Away',
#   'trailer': 'https://www.youtube.com/embed/ByXuk9QqQkk',
#   'writers': ['Hayao Miyazaki'],
#   'year': 2001},
#  {'description': "A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run and checks into a remote motel run by a young man under the domination of his mother.",
#   'director': ['Alfred Hitchcock'],
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'id': 'top32',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,1,380,562_.jpg',
#   'imdbid': 'tt0054215',
#   'rank': 32,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Psycho',
#   'trailer': 'https://www.youtube.com/embed/DTJQfFQ40lI',
#   'writers': ['Joseph Stefano (screenplay by)',
#    'Robert Bloch (based on the novel by)'],
#   'year': 1960},
#  {'description': 'A Polish Jewish musician struggles to survive the destruction of the Warsaw ghetto of World War II.',
#   'director': ['Roman Polanski'],
#   'genre': ['Biography', 'Drama', 'Music'],
#   'id': 'top33',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOWRiZDIxZjktMTA1NC00MDQ2LWEzMjUtMTliZmY3NjQ3ODJiXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UY562_CR14,0,380,562_.jpg',
#   'imdbid': 'tt0253474',
#   'rank': 33,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOWRiZDIxZjktMTA1NC00MDQ2LWEzMjUtMTliZmY3NjQ3ODJiXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR2,0,45,67_AL_.jpg',
#   'title': 'The Pianist',
#   'trailer': 'https://www.youtube.com/embed/BFwGqLa_oAo',
#   'writers': ['Ronald Harwood (screenplay by)',
#    'Wladyslaw Szpilman (based on the book by)'],
#   'year': 2002},
#  {'description': 'Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.',
#   'director': ['Bong Joon Ho'],
#   'genre': ['Drama', 'Thriller'],
#   'id': 'top34',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt6751668',
#   'rank': 34,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Parasite',
#   'trailer': 'https://www.youtube.com/embed/5xH0HfJHsaY',
#   'writers': ['Bong Joon Ho (story by)', 'Han Jin-won (screenplay by)'],
#   'year': 2019},
#  {'description': "12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.",
#   'director': ['Luc Besson'],
#   'genre': ['Action', 'Crime', 'Drama'],
#   'id': 'top35',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOTgyMWQ0ZWUtN2Q2MS00NmY0LWI3OWMtNjFkMzZlNDZjNTk0XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,2,380,562_.jpg',
#   'imdbid': 'tt0110413',
#   'rank': 35,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOTgyMWQ0ZWUtN2Q2MS00NmY0LWI3OWMtNjFkMzZlNDZjNTk0XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Léon: The Professional',
#   'trailer': 'https://www.youtube.com/embed/jawVxq1Iyl0',
#   'writers': ['Luc Besson'],
#   'year': 1994},
#  {'description': 'Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.',
#   'director': ['Roger Allers', 'Rob Minkoff'],
#   'genre': ['Animation', 'Adventure', 'Drama'],
#   'id': 'top36',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYTYxNGMyZTYtMjE3MS00MzNjLWFjNmYtMDk3N2FmM2JiM2M1XkEyXkFqcGdeQXVyNjY5NDU4NzI@._V1_QL75_UX380_CR0,1,380,562_.jpg',
#   'imdbid': 'tt0110357',
#   'rank': 36,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYTYxNGMyZTYtMjE3MS00MzNjLWFjNmYtMDk3N2FmM2JiM2M1XkEyXkFqcGdeQXVyNjY5NDU4NzI@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Lion King',
#   'trailer': 'https://www.youtube.com/embed/eHcZlPpNt0Q',
#   'writers': ['Irene Mecchi (screenplay by)',
#    'Jonathan Roberts (screenplay by)',
#    'Linda Woolverton (screenplay by)'],
#   'year': 1994},
#  {'description': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.',
#   'director': ['Ridley Scott'],
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'id': 'top37',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0172495',
#   'rank': 37,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Gladiator',
#   'trailer': 'https://www.youtube.com/embed/uvbavW31adA',
#   'writers': ['David Franzoni (story)',
#    'John Logan (screenplay)',
#    'William Nicholson (screenplay)'],
#   'year': 1994},
#  {'description': 'A former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did.',
#   'director': ['Tony Kaye'],
#   'genre': ['Crime', 'Drama'],
#   'id': 'top38',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZTJhN2FkYWEtMGI0My00YWM4LWI2MjAtM2UwNjY4MTI2ZTQyXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_QL75_UX380_CR0,1,380,562_.jpg',
#   'imdbid': 'tt0120586',
#   'rank': 38,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZTJhN2FkYWEtMGI0My00YWM4LWI2MjAtM2UwNjY4MTI2ZTQyXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'American History X',
#   'trailer': 'https://www.youtube.com/embed/XfQYHqsiN5g',
#   'writers': ['David McKenna'],
#   'year': 2000},
#  {'description': 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.',
#   'director': ['Martin Scorsese'],
#   'genre': ['Crime', 'Drama', 'Thriller'],
#   'id': 'top39',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_QL75_UY562_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0407887',
#   'rank': 39,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Departed',
#   'trailer': 'https://www.youtube.com/embed/iojhqm0JTW4',
#   'writers': ['William Monahan (screenplay)',
#    'Alan Mak (2002 screenplay Mou gaan dou)',
#    'Felix Chong (2002 screenplay Mou gaan dou)'],
#   'year': 1998},
#  {'description': 'A sole survivor tells of the twisty events leading up to a horrific gun battle on a boat, which began when five criminals met at a seemingly random police lineup.',
#   'director': ['Bryan Singer'],
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'id': 'top40',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYTViNjMyNmUtNDFkNC00ZDRlLThmMDUtZDU2YWE4NGI2ZjVmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,2,380,562_.jpg',
#   'imdbid': 'tt0114814',
#   'rank': 40,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYTViNjMyNmUtNDFkNC00ZDRlLThmMDUtZDU2YWE4NGI2ZjVmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'The Usual Suspects',
#   'trailer': 'https://www.youtube.com/embed/Q0eCiCinc4E',
#   'writers': ['Christopher McQuarrie'],
#   'year': 1995},
#  {'description': 'After a tragic accident, two stage magicians in 1890s London engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.',
#   'director': ['Christopher Nolan'],
#   'genre': ['Drama', 'Mystery', 'Sci-Fi'],
#   'id': 'top41',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0482571',
#   'rank': 41,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Prestige',
#   'trailer': 'https://www.youtube.com/embed/RLtaA9fFNXU',
#   'writers': ['Jonathan Nolan (screenplay)',
#    'Christopher Nolan (screenplay)',
#    'Christopher Priest (novel)'],
#   'year': 2006},
#  {'description': "A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.",
#   'director': ['Damien Chazelle'],
#   'genre': ['Drama', 'Music'],
#   'id': 'top42',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOTA5NDZlZGUtMjAxOS00YTRkLTkwYmMtYWQ0NWEwZDZiNjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt2582802',
#   'rank': 42,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOTA5NDZlZGUtMjAxOS00YTRkLTkwYmMtYWQ0NWEwZDZiNjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Whiplash',
#   'trailer': 'https://www.youtube.com/embed/7d_jQycdQGo',
#   'writers': ['Damien Chazelle'],
#   'year': 2014},
#  {'description': 'A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive husband escape the Nazis in French Morocco.',
#   'director': ['Michael Curtiz'],
#   'genre': ['Drama', 'Romance', 'War'],
#   'id': 'top43',
#   'image': 'https://m.media-amazon.com/images/M/MV5BY2IzZGY2YmEtYzljNS00NTM5LTgwMzUtMzM1NjQ4NGI0OTk0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_QL75_UX380_CR0,5,380,562_.jpg',
#   'imdbid': 'tt0034583',
#   'rank': 43,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BY2IzZGY2YmEtYzljNS00NTM5LTgwMzUtMzM1NjQ4NGI0OTk0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Casablanca',
#   'trailer': 'https://www.youtube.com/embed/BkL9l7qovsE',
#   'writers': ['Julius J. Epstein (screenplay)',
#    'Philip G. Epstein (screenplay)',
#    'Howard Koch (screenplay)'],
#   'year': 1942},
#  {'description': 'After he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.',
#   'director': ['Olivier Nakache', 'Éric Toledano'],
#   'genre': ['Biography', 'Comedy', 'Drama'],
#   'id': 'top44',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMTYxNDA3MDQwNl5BMl5BanBnXkFtZTcwNTU4Mzc1Nw@@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt1675434',
#   'rank': 44,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTYxNDA3MDQwNl5BMl5BanBnXkFtZTcwNTU4Mzc1Nw@@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'The Intouchables',
#   'trailer': 'https://www.youtube.com/embed/oK5hMNxqsFA',
#   'writers': ['Olivier Nakache',
#    'Philippe Pozzo di Borgo (adapted from his autobiographical tale Le Second Souffle)',
#    'Éric Toledano'],
#   'year': 2011},
#  {'description': "When a ronin requesting seppuku at a feudal lord's palace is told of the brutal suicide of another ronin who previously visited, he reveals how their pasts are intertwined - and in doing so challenges the clan's integrity.",
#   'director': ['Masaki Kobayashi'],
#   'genre': ['Action', 'Drama', 'Mystery'],
#   'id': 'top45',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYjBmYTQ1NjItZWU5MS00YjI0LTg2OTYtYmFkN2JkMmNiNWVkXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_QL75_UY562_CR17,0,380,562_.jpg',
#   'imdbid': 'tt0056058',
#   'rank': 45,
#   'rating': '8.6',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYjBmYTQ1NjItZWU5MS00YjI0LTg2OTYtYmFkN2JkMmNiNWVkXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_UY67_CR2,0,45,67_AL_.jpg',
#   'title': 'Harakiri',
#   'trailer': 'https://www.youtube.com/embed/gfABwM-Ppng',
#   'writers': ['Yasuhiko Takiguchi (novel "Ibun rônin ki")',
#    'Shinobu Hashimoto (screenplay)'],
#   'year': 1962},
#  {'description': 'A young boy and his little sister struggle to survive in Japan during World War II.',
#   'director': ['Isao Takahata'],
#   'genre': ['Animation'],
#   'id': 'top46',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZmY2NjUzNDQtNTgxNC00M2Q4LTljOWQtMjNjNDBjNWUxNmJlXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_QL75_UX380_CR0,4,380,562_.jpg',
#   'imdbid': 'tt0095327',
#   'rank': 46,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZmY2NjUzNDQtNTgxNC00M2Q4LTljOWQtMjNjNDBjNWUxNmJlXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Grave of the Fireflies',
#   'trailer': 'https://www.youtube.com/embed/4vPeTSRd580',
#   'writers': ['Akiyuki Nosaka (novel)', 'Isao Takahata'],
#   'year': 1988},
#  {'description': 'The Tramp struggles to live in modern industrial society with the help of a young homeless woman.',
#   'director': ['Charles Chaplin'],
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'id': 'top47',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYjJiZjMzYzktNjU0NS00OTkxLWEwYzItYzdhYWJjN2QzMTRlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,15,380,562_.jpg',
#   'imdbid': 'tt0027977',
#   'rank': 47,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYjJiZjMzYzktNjU0NS00OTkxLWEwYzItYzdhYWJjN2QzMTRlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Modern Times',
#   'trailer': 'https://www.youtube.com/embed/GLeDdzGUTq0',
#   'writers': ['Charles Chaplin'],
#   'year': 1936},
#  {'description': 'A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad.',
#   'director': ['Sergio Leone'],
#   'genre': ['Western'],
#   'id': 'top48',
#   'image': 'https://m.media-amazon.com/images/M/MV5BODQ3NDExOGYtMzI3Mi00NWRlLTkwNjAtNjc4MDgzZGJiZTA1XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,3,380,562_.jpg',
#   'imdbid': 'tt0064116',
#   'rank': 48,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BODQ3NDExOGYtMzI3Mi00NWRlLTkwNjAtNjc4MDgzZGJiZTA1XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Once Upon a Time in the West',
#   'trailer': 'https://www.youtube.com/embed/c8CJ6L0I6W8',
#   'writers': ['Sergio Donati (screenplay by)',
#    'Sergio Leone (screenplay by)',
#    'Dario Argento (from a story by)'],
#   'year': 1968},
#  {'description': 'A wheelchair-bound photographer spies on his neighbors from his Greenwich Village courtyard apartment window, and becomes convinced one of them has committed murder, despite the skepticism of his fashion-model girlfriend.',
#   'director': ['Alfred Hitchcock'],
#   'genre': ['Mystery', 'Thriller'],
#   'id': 'top49',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UY562_CR2,0,380,562_.jpg',
#   'imdbid': 'tt0047396',
#   'rank': 49,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Rear Window',
#   'trailer': 'https://www.youtube.com/embed/m01YktiEZCw',
#   'writers': ['John Michael Hayes (screenplay)',
#    'Cornell Woolrich (short story)'],
#   'year': 1954},
#  {'description': 'The crew of a commercial spacecraft encounter a deadly lifeform after investigating an unknown transmission.',
#   'director': ['Ridley Scott'],
#   'genre': ['Horror', 'Sci-Fi'],
#   'id': 'top50',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOGQzZTBjMjQtOTVmMS00NGE5LWEyYmMtOGQ1ZGZjNmRkYjFhXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,6,380,562_.jpg',
#   'imdbid': 'tt0078748',
#   'rank': 50,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOGQzZTBjMjQtOTVmMS00NGE5LWEyYmMtOGQ1ZGZjNmRkYjFhXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Alien',
#   'trailer': 'https://www.youtube.com/embed/jQ5lPt9edzQ',
#   'writers': ["Dan O'Bannon (screenplay by)", 'Ronald Shusett (story by)'],
#   'year': 1979},
#  {'description': 'With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has fallen in love with a sightless flower girl accumulates money to be able to help her medically.',
#   'director': ['Charles Chaplin'],
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'id': 'top51',
#   'image': 'https://m.media-amazon.com/images/M/MV5BY2I4MmM1N2EtM2YzOS00OWUzLTkzYzctNDc5NDg2N2IyODJmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,4,380,562_.jpg',
#   'imdbid': 'tt0021749',
#   'rank': 51,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BY2I4MmM1N2EtM2YzOS00OWUzLTkzYzctNDc5NDg2N2IyODJmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'City Lights',
#   'trailer': 'https://www.youtube.com/embed/7vl7F8S4cpQ',
#   'writers': ['Charles Chaplin',
#    'Harry Carr (uncredited)',
#    'Harry Crocker (uncredited)'],
#   'year': 1931},
#  {'description': "A filmmaker recalls his childhood when falling in love with the pictures at the cinema of his home village and forms a deep friendship with the cinema's projectionist.",
#   'director': ['Giuseppe Tornatore'],
#   'genre': ['Drama', 'Romance'],
#   'id': 'top52',
#   'image': 'https://m.media-amazon.com/images/M/MV5BM2FhYjEyYmYtMDI1Yy00YTdlLWI2NWQtYmEzNzAxOGY1NjY2XkEyXkFqcGdeQXVyNTA3NTIyNDg@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0095765',
#   'rank': 52,
#   'rating': '8.5',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BM2FhYjEyYmYtMDI1Yy00YTdlLWI2NWQtYmEzNzAxOGY1NjY2XkEyXkFqcGdeQXVyNTA3NTIyNDg@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Cinema Paradiso',
#   'trailer': 'https://www.youtube.com/embed/C2-GX0Tltgw',
#   'writers': ['Giuseppe Tornatore (story)',
#    'Vanna Paoli (collaborating writer)'],
#   'year': 1988},
#  {'description': 'A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god.',
#   'director': ['Francis Ford Coppola'],
#   'genre': ['Drama', 'Mystery', 'War'],
#   'id': 'top53',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYmQyNTA1ZGItNjZjMi00NzFlLWEzMWEtNWMwN2Q2MjJhYzEyXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_QL75_UX380_CR0,11,380,562_.jpg',
#   'imdbid': 'tt0078788',
#   'rank': 53,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYmQyNTA1ZGItNjZjMi00NzFlLWEzMWEtNWMwN2Q2MjJhYzEyXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Apocalypse Now',
#   'trailer': 'https://www.youtube.com/embed/FTjG-Aux_yQ',
#   'writers': ['John Milius',
#    'Francis Ford Coppola',
#    'Michael Herr (narration)'],
#   'year': 1979},
#  {'description': "A man with short-term memory loss attempts to track down his wife's murderer.",
#   'director': ['Christopher Nolan'],
#   'genre': ['Mystery', 'Thriller'],
#   'id': 'top54',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZTcyNjk1MjgtOWI3Mi00YzQwLWI5MTktMzY4ZmI2NDAyNzYzXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UY562_CR2,0,380,562_.jpg',
#   'imdbid': 'tt0209144',
#   'rank': 54,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZTcyNjk1MjgtOWI3Mi00YzQwLWI5MTktMzY4ZmI2NDAyNzYzXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Memento',
#   'trailer': 'https://www.youtube.com/embed/4CV41hoyS8A',
#   'writers': ['Christopher Nolan (screenplay)',
#    'Jonathan Nolan (short story "Memento Mori")'],
#   'year': 2000},
#  {'description': 'Archaeology professor Indiana Jones ventures to seize a biblical artefact known as the Ark of the Covenant. While doing so, he puts up a fight against Renee and a troop of Nazis.',
#   'director': ['Steven Spielberg'],
#   'genre': ['Action', 'Adventure'],
#   'id': 'top55',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNTU2ODkyY2MtMjU1NC00NjE1LWEzYjgtMWQ3MzRhMTE0NDc0XkEyXkFqcGdeQXVyMjM4MzQ4OTQ@._V1_QL75_UY562_CR1,0,380,562_.jpg',
#   'imdbid': 'tt0082971',
#   'rank': 55,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNTU2ODkyY2MtMjU1NC00NjE1LWEzYjgtMWQ3MzRhMTE0NDc0XkEyXkFqcGdeQXVyMjM4MzQ4OTQ@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Indiana Jones and the Raiders of the Lost Ark',
#   'trailer': 'https://www.youtube.com/embed/Rh_BJXG1-44',
#   'writers': ['Lawrence Kasdan (screenplay by)',
#    'George Lucas (story by)',
#    'Philip Kaufman (story by)'],
#   'year': 1981},
#  {'description': 'With the help of a German bounty-hunter, a freed slave sets out to rescue his wife from a brutal plantation-owner in Mississippi.',
#   'director': ['Quentin Tarantino'],
#   'genre': ['Drama', 'Western'],
#   'id': 'top56',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMjIyNTQ5NjQ1OV5BMl5BanBnXkFtZTcwODg1MDU4OA@@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt1853728',
#   'rank': 56,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMjIyNTQ5NjQ1OV5BMl5BanBnXkFtZTcwODg1MDU4OA@@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Django Unchained',
#   'trailer': 'https://www.youtube.com/embed/0fUCuvNlOCg',
#   'writers': ['Quentin Tarantino'],
#   'year': 2012},
#  {'description': 'In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.',
#   'director': ['Andrew Stanton'],
#   'genre': ['Animation', 'Adventure', 'Family'],
#   'id': 'top57',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMjExMTg5OTU0NF5BMl5BanBnXkFtZTcwMjMxMzMzMw@@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0910970',
#   'rank': 57,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMjExMTg5OTU0NF5BMl5BanBnXkFtZTcwMjMxMzMzMw@@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'WALL·E',
#   'trailer': 'https://www.youtube.com/embed/CZ1CATNbXg0',
#   'writers': ['Andrew Stanton (original story by)',
#    'Pete Docter (original story by)',
#    'Jim Reardon (screenplay by)'],
#   'year': 2008},
# ...
#   'genre': ['Drama', 'Romance'],
#   'id': 'top82',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOTI0MzcxMTYtZDVkMy00NjY1LTgyMTYtZmUxN2M3NmQ2NWJhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,9,380,562_.jpg',
#   'imdbid': 'tt0119217',
#   'rank': 82,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOTI0MzcxMTYtZDVkMy00NjY1LTgyMTYtZmUxN2M3NmQ2NWJhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Good Will Hunting',
#   'trailer': 'https://www.youtube.com/embed/PaZVjZEFkRs',
#   'writers': ['Matt Damon', 'Ben Affleck'],
#   'year': 1997},
#  {'description': 'Two strangers find themselves linked in a bizarre way. When a connection forms, will distance be the only thing to keep them apart?',
#   'director': ['Makoto Shinkai'],
#   'genre': ['Animation', 'Drama', 'Fantasy'],
#   'id': 'top83',
#   'image': 'https://m.media-amazon.com/images/M/MV5BODRmZDVmNzUtZDA4ZC00NjhkLWI2M2UtN2M0ZDIzNDcxYThjL2ltYWdlXkEyXkFqcGdeQXVyNTk0MzMzODA@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt5311514',
#   'rank': 83,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BODRmZDVmNzUtZDA4ZC00NjhkLWI2M2UtN2M0ZDIzNDcxYThjL2ltYWdlXkEyXkFqcGdeQXVyNTk0MzMzODA@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Your Name.',
#   'trailer': 'https://www.youtube.com/embed/xU47nhruN-Q',
#   'writers': ['Makoto Shinkai (based on his novel)',
#    'Clark Cheng (english script)'],
#   'year': 2016},
#  {'description': 'The drug-induced utopias of four Coney Island people are shattered when their addictions run deep.',
#   'director': ['Darren Aronofsky'],
#   'genre': ['Drama'],
#   'id': 'top84',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOTdiNzJlOWUtNWMwNS00NmFlLWI0YTEtZmI3YjIzZWUyY2Y3XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,4,380,562_.jpg',
#   'imdbid': 'tt0180093',
#   'rank': 84,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOTdiNzJlOWUtNWMwNS00NmFlLWI0YTEtZmI3YjIzZWUyY2Y3XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Requiem for a Dream',
#   'trailer': 'https://www.youtube.com/embed/QBwzN4v1vA0',
#   'writers': ['Hubert Selby Jr. (based on the book by)',
#    'Darren Aronofsky (screenplay)'],
#   'year': 2000},
#  {'description': "The toys are mistakenly delivered to a day-care center instead of the attic right before Andy leaves for college, and it's up to Woody to convince the other toys that they weren't abandoned and to return home.",
#   'director': ['Lee Unkrich'],
#   'genre': ['Animation', 'Adventure', 'Comedy'],
#   'id': 'top85',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_QL75_UY562_CR9,0,380,562_.jpg',
#   'imdbid': 'tt0435761',
#   'rank': 85,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_UY67_CR1,0,45,67_AL_.jpg',
#   'title': 'Toy Story 3',
#   'trailer': 'https://www.youtube.com/embed/JcpWXaA2qeg',
#   'writers': ['John Lasseter (story by)',
#    'Andrew Stanton (story by)',
#    'Lee Unkrich (story by)'],
#   'year': 2010},
#  {'description': 'A silent film star falls for a chorus girl just as he and his delusionally jealous screen partner are trying to make the difficult transition to talking pictures in 1920s Hollywood.',
#   'director': ['Stanley Donen', 'Gene Kelly'],
#   'genre': ['Comedy', 'Musical', 'Romance'],
#   'id': 'top86',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZDRjNGViMjQtOThlMi00MTA3LThkYzQtNzJkYjBkMGE0YzE1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_QL75_UY562_CR3,0,380,562_.jpg',
#   'imdbid': 'tt0045152',
#   'rank': 86,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZDRjNGViMjQtOThlMi00MTA3LThkYzQtNzJkYjBkMGE0YzE1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': "Singin' in the Rain",
#   'trailer': 'https://www.youtube.com/embed/5_EVHeNEIJY',
#   'writers': ['Betty Comden (story by)', 'Adolph Green (story by)'],
#   'year': 1952},
#  {'description': 'Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of the world called them "idiots".',
#   'director': ['Rajkumar Hirani'],
#   'genre': ['Comedy', 'Drama'],
#   'id': 'top87',
#   'image': 'https://m.media-amazon.com/images/M/MV5BNTkyOGVjMGEtNmQzZi00NzFlLTlhOWQtODYyMDc2ZGJmYzFhXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UY562_CR5,0,380,562_.jpg',
#   'imdbid': 'tt1187043',
#   'rank': 87,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BNTkyOGVjMGEtNmQzZi00NzFlLTlhOWQtODYyMDc2ZGJmYzFhXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR1,0,45,67_AL_.jpg',
#   'title': '3 Idiots',
#   'trailer': 'https://www.youtube.com/embed/xvszmNXdM4w',
#   'writers': ['Rajkumar Hirani (screenplay)',
#    'Abhijat Joshi (screenplay)',
#    'Vidhu Vinod Chopra (screenplay associate)'],
#   'year': 2009},
#  {'description': "An executive of a Yokohama shoe company becomes a victim of extortion when his chauffeur's son is kidnapped by mistake and held for ransom.",
#   'director': ['Akira Kurosawa'],
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'id': 'top88',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZGQ1NWZlYjctNDJmOS00MmU2LTg1ODItNmZiM2ZkNzJhNDI0XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UY562_CR9,0,380,562_.jpg',
#   'imdbid': 'tt0057565',
#   'rank': 88,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZGQ1NWZlYjctNDJmOS00MmU2LTg1ODItNmZiM2ZkNzJhNDI0XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UY67_CR1,0,45,67_AL_.jpg',
#   'title': 'High and Low',
#   'trailer': 'https://www.youtube.com/embed/LV3z2Ytxu90',
#   'writers': ['Hideo Oguni (screenplay)',
#    'Ryûzô Kikushima (screenplay)',
#    'Eijirô Hisaita (screenplay)'],
#   'year': 1963},
#  {'description': "After a daring mission to rescue Han Solo from Jabba the Hutt, the Rebels dispatch to Endor to destroy the second Death Star. Meanwhile, Luke struggles to help Darth Vader back from the dark side without falling into the Emperor's trap.",
#   'director': ['Richard Marquand'],
#   'genre': ['Action', 'Adventure', 'Fantasy'],
#   'id': 'top89',
#   'image': 'https://m.media-amazon.com/images/M/MV5BOWZlMjFiYzgtMTUzNC00Y2IzLTk1NTMtZmNhMTczNTk0ODk1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_QL75_UX380_CR0,13,380,562_.jpg',
#   'imdbid': 'tt0086190',
#   'rank': 89,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BOWZlMjFiYzgtMTUzNC00Y2IzLTk1NTMtZmNhMTczNTk0ODk1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Star Wars: Episode VI - Return of the Jedi',
#   'trailer': 'https://www.youtube.com/embed/p4vIFhk621Q',
#   'writers': ['Lawrence Kasdan (screenplay by)',
#    'George Lucas (screenplay by)'],
#   'year': 1983},
#  {'description': 'After uncovering a mysterious artifact buried beneath the Lunar surface, a spacecraft is sent to Jupiter to find its origins - a spacecraft manned by two men and the supercomputer H.A.L. 9000.',
#   'director': ['Stanley Kubrick'],
#   'genre': ['Adventure', 'Sci-Fi'],
#   'id': 'top90',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMmNlYzRiNDctZWNhMi00MzI4LThkZTctMTUzMmZkMmFmNThmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0062622',
#   'rank': 90,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMmNlYzRiNDctZWNhMi00MzI4LThkZTctMTUzMmZkMmFmNThmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': '2001: A Space Odyssey',
#   'trailer': 'https://www.youtube.com/embed/UgGCScAV7qU',
#   'writers': ['Stanley Kubrick (screenplay by)',
#    'Arthur C. Clarke (screenplay by)'],
#   'year': 1968},
#  {'description': 'When their relationship turns sour, a couple undergoes a medical procedure to have each other erased from their memories.',
#   'director': ['Michel Gondry'],
#   'genre': ['Drama', 'Romance', 'Sci-Fi'],
#   'id': 'top91',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMTY4NzcwODg3Nl5BMl5BanBnXkFtZTcwNTEwOTMyMw@@._V1_QL75_UX380_CR0,0,380,562_.jpg',
#   'imdbid': 'tt0338013',
#   'rank': 91,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTY4NzcwODg3Nl5BMl5BanBnXkFtZTcwNTEwOTMyMw@@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Eternal Sunshine of the Spotless Mind',
#   'trailer': 'https://www.youtube.com/embed/07-QBnEkgXU',
#   'writers': ['Charlie Kaufman (story)',
#    'Michel Gondry (story)',
#    'Pierre Bismuth (story)'],
#   'year': 2004},
#  {'description': 'While serving a five-year sentence for a violent crime, a 12-year-old boy sues his parents for neglect.',
#   'director': ['Nadine Labaki'],
#   'genre': ['Drama'],
#   'id': 'top92',
#   'image': 'https://m.media-amazon.com/images/M/MV5BY2Y3OWNkMTctYzNjYS00NWVkLTg4OWEtY2YxN2I3NDhlYzE0XkEyXkFqcGdeQXVyMTI3ODAyMzE2._V1_QL75_UY562_CR7,0,380,562_.jpg',
#   'imdbid': 'tt8267604',
#   'rank': 92,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BY2Y3OWNkMTctYzNjYS00NWVkLTg4OWEtY2YxN2I3NDhlYzE0XkEyXkFqcGdeQXVyMTI3ODAyMzE2._V1_UY67_CR1,0,45,67_AL_.jpg',
#   'title': 'Capernaum',
#   'trailer': 'https://www.youtube.com/embed/ULUo0048xZE',
#   'writers': ['Nadine Labaki (screenplay)',
#    'Jihad Hojeily (screenplay)',
#    'Michelle Keserwany (screenplay)'],
#   'year': 2018},
#  {'description': 'When a simple jewelry heist goes horribly wrong, the surviving criminals begin to suspect that one of them is a police informant.',
#   'director': ['Quentin Tarantino'],
#   'genre': ['Crime', 'Thriller'],
#   'id': 'top93',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZmExNmEwYWItYmQzOS00YjA5LTk2MjktZjEyZDE1Y2QxNjA1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_QL75_UX380_CR0,2,380,562_.jpg',
#   'imdbid': 'tt0105236',
#   'rank': 93,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZmExNmEwYWItYmQzOS00YjA5LTk2MjktZjEyZDE1Y2QxNjA1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Reservoir Dogs',
#   'trailer': 'https://www.youtube.com/embed/vayksn4Y93A',
#   'writers': ['Quentin Tarantino (background radio dialogue written by)',
#    'Roger Avary (background radio dialogue written by)'],
#   'year': 1992},
#  {'description': "A teacher lives a lonely life, all the while struggling over his son's custody. His life slowly gets better as he finds love and receives good news from his son, but his new luck is about to be brutally shattered by an innocent little lie.",
#   'director': ['Thomas Vinterberg'],
#   'genre': ['Drama'],
#   'id': 'top94',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMTg2NDg3ODg4NF5BMl5BanBnXkFtZTcwNzk3NTc3Nw@@._V1_QL75_UY562_CR7,0,380,562_.jpg',
#   'imdbid': 'tt2106476',
#   'rank': 94,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTg2NDg3ODg4NF5BMl5BanBnXkFtZTcwNzk3NTc3Nw@@._V1_UY67_CR1,0,45,67_AL_.jpg',
#   'title': 'The Hunt',
#   'trailer': 'https://www.youtube.com/embed/YsYn6L5fF9Q',
#   'writers': ['Thomas Vinterberg (screenplay)',
#    'Tobias Lindholm (screenplay)'],
#   'year': 2012},
#  {'description': "Following the death of publishing tycoon Charles Foster Kane, reporters scramble to uncover the meaning of his final utterance: 'Rosebud.'",
#   'director': ['Orson Welles'],
#   'genre': ['Drama', 'Mystery'],
#   'id': 'top95',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYjBiOTYxZWItMzdiZi00NjlkLWIzZTYtYmFhZjhiMTljOTdkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,4,380,562_.jpg',
#   'imdbid': 'tt0033467',
#   'rank': 95,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYjBiOTYxZWItMzdiZi00NjlkLWIzZTYtYmFhZjhiMTljOTdkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Citizen Kane',
#   'trailer': 'https://www.youtube.com/embed/8dxh3lwdOFw',
#   'writers': ['Herman J. Mankiewicz (original screen play)',
#    'Orson Welles (original screen play)',
#    'John Houseman (contributing writer)'],
#   'year': 1941},
#  {'description': 'The story of T.E. Lawrence, the English officer who successfully united and led the diverse, often warring, Arab tribes during World War I in order to fight the Turks.',
#   'director': ['David Lean'],
#   'genre': ['Adventure', 'Biography', 'Drama'],
#   'id': 'top96',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYWY5ZjhjNGYtZmI2Ny00ODM0LWFkNzgtZmI1YzA2N2MxMzA0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_QL75_UY562_CR5,0,380,562_.jpg',
#   'imdbid': 'tt0056172',
#   'rank': 96,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYWY5ZjhjNGYtZmI2Ny00ODM0LWFkNzgtZmI1YzA2N2MxMzA0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY67_CR0,0,45,67_AL_.jpg',
#   'title': 'Lawrence of Arabia',
#   'trailer': 'https://www.youtube.com/embed/vOlRhGEhG7k',
#   'writers': ['Robert Bolt (screenplay by)', 'Michael Wilson (screenplay by)'],
#   'year': 1962},
#  {'description': 'When the police in a German city are unable to catch a child-murderer, other criminals join in the manhunt.',
#   'director': ['Fritz Lang'],
#   'genre': ['Crime', 'Mystery', 'Thriller'],
#   'id': 'top97',
#   'image': 'https://m.media-amazon.com/images/M/MV5BODA4ODk3OTEzMF5BMl5BanBnXkFtZTgwMTQ2ODMwMzE@._V1_QL75_UX380_CR0,4,380,562_.jpg',
#   'imdbid': 'tt0022100',
#   'rank': 97,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BODA4ODk3OTEzMF5BMl5BanBnXkFtZTgwMTQ2ODMwMzE@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'M',
#   'trailer': 'https://www.youtube.com/embed/nsVproWjN6c',
#   'writers': ['Thea von Harbou (script)',
#    'Fritz Lang (script)',
#    'Egon Jacobsohn (article)'],
#   'year': 1931},
#  {'description': 'After finding an old rifle, a young boy joins the Soviet resistance movement against ruthless German forces and experiences the horrors of World War II.',
#   'director': ['Elem Klimov'],
#   'genre': ['Drama', 'Thriller', 'War'],
#   'id': 'top98',
#   'image': 'https://m.media-amazon.com/images/M/MV5BODM4Njg0NTAtYjI5Ny00ZjAxLTkwNmItZTMxMWU5M2U3M2RjXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,10,380,562_.jpg',
#   'imdbid': 'tt0091251',
#   'rank': 98,
#   'rating': '8.4',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BODM4Njg0NTAtYjI5Ny00ZjAxLTkwNmItZTMxMWU5M2U3M2RjXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX100_CR0,3,100,148_.jpg',
#   'title': 'Come and See',
#   'trailer': 'https://www.youtube.com/embed/UHaSQU-4wss',
#   'writers': ['Ales Adamovich (story)', 'Elem Klimov (screenplay)'],
#   'year': 1985},
#  {'description': 'A New York City advertising executive goes on the run after being mistaken for a government agent by a group of foreign spies, and falls for a woman whose loyalties he begins to doubt.',
#   'director': ['Alfred Hitchcock'],
#   'genre': ['Action', 'Adventure', 'Mystery'],
#   'id': 'top99',
#   'image': 'https://m.media-amazon.com/images/M/MV5BZDA3NDExMTUtMDlhOC00MmQ5LWExZGUtYmI1NGVlZWI4OWNiXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,5,380,562_.jpg',
#   'imdbid': 'tt0053125',
#   'rank': 99,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BZDA3NDExMTUtMDlhOC00MmQ5LWExZGUtYmI1NGVlZWI4OWNiXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'North by Northwest',
#   'trailer': 'https://www.youtube.com/embed/Fx0QuZJVTFE',
#   'writers': ['Ernest Lehman'],
#   'year': 1959},
#  {'description': 'A former San Francisco police detective juggles wrestling with his personal demons and becoming obsessed with the hauntingly beautiful woman he has been hired to trail, who may be deeply disturbed.',
#   'director': ['Alfred Hitchcock'],
#   'genre': ['Mystery', 'Romance', 'Thriller'],
#   'id': 'top100',
#   'image': 'https://m.media-amazon.com/images/M/MV5BYTE4ODEwZDUtNDFjOC00NjAxLWEzYTQtYTI1NGVmZmFlNjdiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,13,380,562_.jpg',
#   'imdbid': 'tt0052357',
#   'rank': 100,
#   'rating': '8.3',
#   'thumbnail': 'https://m.media-amazon.com/images/M/MV5BYTE4ODEwZDUtNDFjOC00NjAxLWEzYTQtYTI1NGVmZmFlNjdiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg',
#   'title': 'Vertigo',
#   'trailer': 'https://www.youtube.com/embed/Z5jvQwwHQNY',
#   'writers': ['Alec Coppel (screenplay by)',
#    'Samuel A. Taylor (screenplay by)',
#    'Pierre Boileau (based on the novel "D\'Entre Les Morts" by)'],
#   'year': 1958}]

# %%
type(y)
# Out:
# list

# %% [markdown]
# ### 4. json.load() - method takes a file object and returns the json object

# %%
with open('{}/movies.json'.format(os.getcwd()),'r') as infile:
    x = json.load(infile)
    infile.close()
print(x)
# Out:
# [{'description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 'director': ['Frank Darabont'], 'genre': ['Drama'], 'id': 'top1', 'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg', 'imdbid': 'tt0111161', 'rank': 1, 'rating': '9.3', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg', 'title': 'The Shawshank Redemption', 'trailer': 'https://www.youtube.com/embed/NmzuHjWmXOc', 'writers': ['Stephen King (based on the short novel "Rita Hayworth and the Shawshank Redemption" by)', 'Frank Darabont (screenplay by)'], 'year': 1994}, {'description': 'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.', 'director': ['Francis Ford Coppola'], 'genre': ['Crime', 'Drama'], 'id': 'top2', 'image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR8,0,380,562_.jpg', 'imdbid': 'tt0068646', 'rank': 2, 'rating': '9.2', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg', 'title': 'The Godfather', 'trailer': 'https://www.youtube.com/embed/rqGJyUB1Q3s', 'writers': ['Mario Puzo (screenplay by)', 'Francis Ford Coppola (screenplay by)'], 'year': 1972}, {'description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.', 'director': ['Christopher Nolan'], 'genre': ['Action', 'Crime', 'Drama'], 'id': 'top3', 'image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg', 'imdbid': 'tt0468569', 'rank': 3, 'rating': '9.0', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg', 'title': 'The Dark Knight', 'trailer': 'https://www.youtube.com/embed/EXeTwQWrcwY', 'writers': ['Jonathan Nolan (screenplay)', 'Christopher Nolan (screenplay)', 'David S. Goyer (story)'], 'year': 2008}, {'description': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'director': ['Francis Ford Coppola'], 'genre': ['Crime', 'Drama'], 'id': 'top4', 'image': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR7,0,380,562_.jpg', 'imdbid': 'tt0071562', 'rank': 4, 'rating': '9.0', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg', 'title': 'The Godfather Part II', 'trailer': 'https://www.youtube.com/embed/9O1Iy9od7-A', 'writers': ['Francis Ford Coppola (screenplay by)', 'Mario Puzo (screenplay by)'], 'year': 1974}, {'description': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'director': ['Sidney Lumet'], 'genre': ['Crime', 'Drama'], 'id': 'top5', 'image': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,11,380,562_.jpg', 'imdbid': 'tt0050083', 'rank': 5, 'rating': '9.0', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg', 'title': '12 Angry Men', 'trailer': 'https://www.youtube.com/embed/TEN-2 ...

# %%
type(x)
# Out:
# list

# %%
type(movies_json)
# Out:
# list

# %% [markdown]
# ### We have a copy of movies.json as movies2.json where we have appended
# ### one more dictionary for the movie 'No Country for Old Men'
# We now will try to compare both the json files for differences

# %%
with open('{}/movies2.json'.format(os.getcwd()),'r') as infile:
    z = json.load(infile)
    infile.close()
print(z)
# Out:
# [{'description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 'director': ['Frank Darabont'], 'genre': ['Drama'], 'id': 'top1', 'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg', 'imdbid': 'tt0111161', 'rank': 1, 'rating': '9.3', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg', 'title': 'The Shawshank Redemption', 'trailer': 'https://www.youtube.com/embed/NmzuHjWmXOc', 'writers': ['Stephen King (based on the short novel "Rita Hayworth and the Shawshank Redemption" by)', 'Frank Darabont (screenplay by)'], 'year': 1994}, {'description': 'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.', 'director': ['Francis Ford Coppola'], 'genre': ['Crime', 'Drama'], 'id': 'top2', 'image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR8,0,380,562_.jpg', 'imdbid': 'tt0068646', 'rank': 2, 'rating': '9.2', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg', 'title': 'The Godfather', 'trailer': 'https://www.youtube.com/embed/rqGJyUB1Q3s', 'writers': ['Mario Puzo (screenplay by)', 'Francis Ford Coppola (screenplay by)'], 'year': 1972}, {'description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.', 'director': ['Christopher Nolan'], 'genre': ['Action', 'Crime', 'Drama'], 'id': 'top3', 'image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg', 'imdbid': 'tt0468569', 'rank': 3, 'rating': '9.0', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg', 'title': 'The Dark Knight', 'trailer': 'https://www.youtube.com/embed/EXeTwQWrcwY', 'writers': ['Jonathan Nolan (screenplay)', 'Christopher Nolan (screenplay)', 'David S. Goyer (story)'], 'year': 2008}, {'description': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'director': ['Francis Ford Coppola'], 'genre': ['Crime', 'Drama'], 'id': 'top4', 'image': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR7,0,380,562_.jpg', 'imdbid': 'tt0071562', 'rank': 4, 'rating': '9.0', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg', 'title': 'The Godfather Part II', 'trailer': 'https://www.youtube.com/embed/9O1Iy9od7-A', 'writers': ['Francis Ford Coppola (screenplay by)', 'Mario Puzo (screenplay by)'], 'year': 1974}, {'description': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'director': ['Sidney Lumet'], 'genre': ['Crime', 'Drama'], 'id': 'top5', 'image': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,11,380,562_.jpg', 'imdbid': 'tt0050083', 'rank': 5, 'rating': '9.0', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX45_CR0,0,45,67_AL_.jpg', 'title': '12 Angry Men', 'trailer': 'https://www.youtube.com/embed/TEN-2 ...

# %%
for i in z:      
    if i not in x:   
        print(i)

# As expected the output is returning the last dictionary which we have appended to the copy of the original json
# Out:
# {'description': 'A Serial killer is after a hunter to get back his money sack', 'title': 'No Country for Old Men'}

# %% [markdown]
# ### Flattening a json file using Pandas

# %%
import pandas as pd
movie_df = pd.json_normalize(x)
movie_df
# Out:
#                                           description                director  \
# 0   Two imprisoned men bond over a number of years...        [Frank Darabont]
# 1   The aging patriarch of an organized crime dyna...  [Francis Ford Coppola]
# 2   When the menace known as the Joker wreaks havo...     [Christopher Nolan]
# 3   The early life and career of Vito Corleone in ...  [Francis Ford Coppola]
# 4   The jury in a New York City murder trial is fr...          [Sidney Lumet]
# ..                                                ...                     ...
# 95  The story of T.E. Lawrence, the English office...            [David Lean]
# 96  When the police in a German city are unable to...            [Fritz Lang]
# 97  After finding an old rifle, a young boy joins ...           [Elem Klimov]
# 98  A New York City advertising executive goes on ...      [Alfred Hitchcock]
# 99  A former San Francisco police detective juggle...      [Alfred Hitchcock]
#
#                             genre      id  \
# 0                         [Drama]    top1
# 1                  [Crime, Drama]    top2
# 2          [Action, Crime, Drama]    top3
# 3                  [Crime, Drama]    top4
# 4                  [Crime, Drama]    top5
# ..                            ...     ...
# 95  [Adventure, Biography, Drama]   top96
# 96     [Crime, Mystery, Thriller]   top97
# 97         [Drama, Thriller, War]   top98
# 98   [Action, Adventure, Mystery]   top99
# 99   [Mystery, Romance, Thriller]  top100
#
#                                                 image     imdbid  rank rating  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...  tt0111161     1    9.3
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...  tt0068646     2    9.2
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...  tt0468569     3    9.0
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...  tt0071562     4    9.0
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...  tt0050083     5    9.0
# ..                                                ...        ...   ...    ...
# 95  https://m.media-amazon.com/images/M/MV5BYWY5Zj...  tt0056172    96    8.3
# 96  https://m.media-amazon.com/images/M/MV5BODA4OD...  tt0022100    97    8.3
# 97  https://m.media-amazon.com/images/M/MV5BODM4Nj...  tt0091251    98    8.4
# 98  https://m.media-amazon.com/images/M/MV5BZDA3ND...  tt0053125    99    8.3
# 99  https://m.media-amazon.com/images/M/MV5BYTE4OD...  tt0052357   100    8.3
#
#                                             thumbnail  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                ...
# 95  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 96  https://m.media-amazon.com/images/M/MV5BODA4OD...
# 97  https://m.media-amazon.com/images/M/MV5BODM4Nj...
# 98  https://m.media-amazon.com/images/M/MV5BZDA3ND...
# 99  https://m.media-amazon.com/images/M/MV5BYTE4OD...
#
#                        title                                    trailer  \
# 0   The Shawshank Redemption  https://www.youtube.com/embed/NmzuHjWmXOc
# 1              The Godfather  https://www.youtube.com/embed/rqGJyUB1Q3s
# 2            The Dark Knight  https://www.youtube.com/embed/EXeTwQWrcwY
# 3      The Godfather Part II  https://www.youtube.com/embed/9O1Iy9od7-A
# 4               12 Angry Men  https://www.youtube.com/embed/TEN-2uTi2c0
# ..                       ...                                        ...
# 95        Lawrence of Arabia  https://www.youtube.com/embed/vOlRhGEhG7k
# 96                         M  https://www.youtube.com/embed/nsVproWjN6c
# 97              Come and See  https://www.youtube.com/embed/UHaSQU-4wss
# 98        North by Northwest  https://www.youtube.com/embed/Fx0QuZJVTFE
# 99                   Vertigo  https://www.youtube.com/embed/Z5jvQwwHQNY
#
#                                               writers  year
# 0   [Stephen King (based on the short novel "Rita ...  1994
# 1   [Mario Puzo (screenplay by), Francis Ford Copp...  1972
# 2   [Jonathan Nolan (screenplay), Christopher Nola...  2008
# 3   [Francis Ford Coppola (screenplay by), Mario P...  1974
# 4       [Reginald Rose (teleplay "Twelve Angry Men")]  1957
# ..                                                ...   ...
# 95  [Robert Bolt (screenplay by), Michael Wilson (...  1962
# 96  [Thea von Harbou (script), Fritz Lang (script)...  1931
# 97  [Ales Adamovich (story), Elem Klimov (screenpl...  1985
# 98                                    [Ernest Lehman]  1959
# 99  [Alec Coppel (screenplay by), Samuel A. Taylor...  1958
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Using apply() method to convert 'Director' column values of list type to string

# %%
movie_df['director_str'] = movie_df['director'].apply(lambda x: ','.join([i for i in x]))
movie_df[['director','director_str']]
# Out:
#                   director          director_str
# 0         [Frank Darabont]        Frank Darabont
# 1   [Francis Ford Coppola]  Francis Ford Coppola
# 2      [Christopher Nolan]     Christopher Nolan
# 3   [Francis Ford Coppola]  Francis Ford Coppola
# 4           [Sidney Lumet]          Sidney Lumet
# ..                     ...                   ...
# 95            [David Lean]            David Lean
# 96            [Fritz Lang]            Fritz Lang
# 97           [Elem Klimov]           Elem Klimov
# 98      [Alfred Hitchcock]      Alfred Hitchcock
# 99      [Alfred Hitchcock]      Alfred Hitchcock
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Using apply() method to convert 'genre' column values of list type to string

# %%
movie_df['genre_cleansed'] = movie_df['genre'].apply(lambda x: ','.join([i for i in x]))
movie_df[['genre','genre_cleansed']]
# Out:
#                             genre             genre_cleansed
# 0                         [Drama]                      Drama
# 1                  [Crime, Drama]                Crime,Drama
# 2          [Action, Crime, Drama]         Action,Crime,Drama
# 3                  [Crime, Drama]                Crime,Drama
# 4                  [Crime, Drama]                Crime,Drama
# ..                            ...                        ...
# 95  [Adventure, Biography, Drama]  Adventure,Biography,Drama
# 96     [Crime, Mystery, Thriller]     Crime,Mystery,Thriller
# 97         [Drama, Thriller, War]         Drama,Thriller,War
# 98   [Action, Adventure, Mystery]   Action,Adventure,Mystery
# 99   [Mystery, Romance, Thriller]   Mystery,Romance,Thriller
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Using a custom function to convert the column values that are of list type to string

# %%
def lst_to_str(df, col):
    return df[col].apply(lambda x: ','.join([i for i in x]))

# %%
import pandas as pd
movie_df = pd.json_normalize(x)
movie_df
# Out:
#                                           description                director  \
# 0   Two imprisoned men bond over a number of years...        [Frank Darabont]
# 1   The aging patriarch of an organized crime dyna...  [Francis Ford Coppola]
# 2   When the menace known as the Joker wreaks havo...     [Christopher Nolan]
# 3   The early life and career of Vito Corleone in ...  [Francis Ford Coppola]
# 4   The jury in a New York City murder trial is fr...          [Sidney Lumet]
# ..                                                ...                     ...
# 95  The story of T.E. Lawrence, the English office...            [David Lean]
# 96  When the police in a German city are unable to...            [Fritz Lang]
# 97  After finding an old rifle, a young boy joins ...           [Elem Klimov]
# 98  A New York City advertising executive goes on ...      [Alfred Hitchcock]
# 99  A former San Francisco police detective juggle...      [Alfred Hitchcock]
#
#                             genre      id  \
# 0                         [Drama]    top1
# 1                  [Crime, Drama]    top2
# 2          [Action, Crime, Drama]    top3
# 3                  [Crime, Drama]    top4
# 4                  [Crime, Drama]    top5
# ..                            ...     ...
# 95  [Adventure, Biography, Drama]   top96
# 96     [Crime, Mystery, Thriller]   top97
# 97         [Drama, Thriller, War]   top98
# 98   [Action, Adventure, Mystery]   top99
# 99   [Mystery, Romance, Thriller]  top100
#
#                                                 image     imdbid  rank rating  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...  tt0111161     1    9.3
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...  tt0068646     2    9.2
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...  tt0468569     3    9.0
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...  tt0071562     4    9.0
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...  tt0050083     5    9.0
# ..                                                ...        ...   ...    ...
# 95  https://m.media-amazon.com/images/M/MV5BYWY5Zj...  tt0056172    96    8.3
# 96  https://m.media-amazon.com/images/M/MV5BODA4OD...  tt0022100    97    8.3
# 97  https://m.media-amazon.com/images/M/MV5BODM4Nj...  tt0091251    98    8.4
# 98  https://m.media-amazon.com/images/M/MV5BZDA3ND...  tt0053125    99    8.3
# 99  https://m.media-amazon.com/images/M/MV5BYTE4OD...  tt0052357   100    8.3
#
#                                             thumbnail  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                ...
# 95  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 96  https://m.media-amazon.com/images/M/MV5BODA4OD...
# 97  https://m.media-amazon.com/images/M/MV5BODM4Nj...
# 98  https://m.media-amazon.com/images/M/MV5BZDA3ND...
# 99  https://m.media-amazon.com/images/M/MV5BYTE4OD...
#
#                        title                                    trailer  \
# 0   The Shawshank Redemption  https://www.youtube.com/embed/NmzuHjWmXOc
# 1              The Godfather  https://www.youtube.com/embed/rqGJyUB1Q3s
# 2            The Dark Knight  https://www.youtube.com/embed/EXeTwQWrcwY
# 3      The Godfather Part II  https://www.youtube.com/embed/9O1Iy9od7-A
# 4               12 Angry Men  https://www.youtube.com/embed/TEN-2uTi2c0
# ..                       ...                                        ...
# 95        Lawrence of Arabia  https://www.youtube.com/embed/vOlRhGEhG7k
# 96                         M  https://www.youtube.com/embed/nsVproWjN6c
# 97              Come and See  https://www.youtube.com/embed/UHaSQU-4wss
# 98        North by Northwest  https://www.youtube.com/embed/Fx0QuZJVTFE
# 99                   Vertigo  https://www.youtube.com/embed/Z5jvQwwHQNY
#
#                                               writers  year
# 0   [Stephen King (based on the short novel "Rita ...  1994
# 1   [Mario Puzo (screenplay by), Francis Ford Copp...  1972
# 2   [Jonathan Nolan (screenplay), Christopher Nola...  2008
# 3   [Francis Ford Coppola (screenplay by), Mario P...  1974
# 4       [Reginald Rose (teleplay "Twelve Angry Men")]  1957
# ..                                                ...   ...
# 95  [Robert Bolt (screenplay by), Michael Wilson (...  1962
# 96  [Thea von Harbou (script), Fritz Lang (script)...  1931
# 97  [Ales Adamovich (story), Elem Klimov (screenpl...  1985
# 98                                    [Ernest Lehman]  1959
# 99  [Alec Coppel (screenplay by), Samuel A. Taylor...  1958
#
# [100 rows x 13 columns]

# %%
movie_df['director_str']=lst_to_str(movie_df, 'director')
movie_df[['director','director_str']]
# Out:
#                   director          director_str
# 0         [Frank Darabont]        Frank Darabont
# 1   [Francis Ford Coppola]  Francis Ford Coppola
# 2      [Christopher Nolan]     Christopher Nolan
# 3   [Francis Ford Coppola]  Francis Ford Coppola
# 4           [Sidney Lumet]          Sidney Lumet
# ..                     ...                   ...
# 95            [David Lean]            David Lean
# 96            [Fritz Lang]            Fritz Lang
# 97           [Elem Klimov]           Elem Klimov
# 98      [Alfred Hitchcock]      Alfred Hitchcock
# 99      [Alfred Hitchcock]      Alfred Hitchcock
#
# [100 rows x 2 columns]

# %%
movie_df['genre_str']=lst_to_str(movie_df, 'genre')
movie_df[['genre','genre_str']]
# Out:
#                             genre                  genre_str
# 0                         [Drama]                      Drama
# 1                  [Crime, Drama]                Crime,Drama
# 2          [Action, Crime, Drama]         Action,Crime,Drama
# 3                  [Crime, Drama]                Crime,Drama
# 4                  [Crime, Drama]                Crime,Drama
# ..                            ...                        ...
# 95  [Adventure, Biography, Drama]  Adventure,Biography,Drama
# 96     [Crime, Mystery, Thriller]     Crime,Mystery,Thriller
# 97         [Drama, Thriller, War]         Drama,Thriller,War
# 98   [Action, Adventure, Mystery]   Action,Adventure,Mystery
# 99   [Mystery, Romance, Thriller]   Mystery,Romance,Thriller
#
# [100 rows x 2 columns]

# %%
movie_df['writers_str']=lst_to_str(movie_df, 'writers')
movie_df[['writers','writers_str']]
# Out:
#                                               writers  \
# 0   [Stephen King (based on the short novel "Rita ...
# 1   [Mario Puzo (screenplay by), Francis Ford Copp...
# 2   [Jonathan Nolan (screenplay), Christopher Nola...
# 3   [Francis Ford Coppola (screenplay by), Mario P...
# 4       [Reginald Rose (teleplay "Twelve Angry Men")]
# ..                                                ...
# 95  [Robert Bolt (screenplay by), Michael Wilson (...
# 96  [Thea von Harbou (script), Fritz Lang (script)...
# 97  [Ales Adamovich (story), Elem Klimov (screenpl...
# 98                                    [Ernest Lehman]
# 99  [Alec Coppel (screenplay by), Samuel A. Taylor...
#
#                                           writers_str
# 0   Stephen King (based on the short novel "Rita H...
# 1   Mario Puzo (screenplay by),Francis Ford Coppol...
# 2   Jonathan Nolan (screenplay),Christopher Nolan ...
# 3   Francis Ford Coppola (screenplay by),Mario Puz...
# 4         Reginald Rose (teleplay "Twelve Angry Men")
# ..                                                ...
# 95  Robert Bolt (screenplay by),Michael Wilson (sc...
# 96  Thea von Harbou (script),Fritz Lang (script),E...
# 97    Ales Adamovich (story),Elem Klimov (screenplay)
# 98                                      Ernest Lehman
# 99  Alec Coppel (screenplay by),Samuel A. Taylor (...
#
# [100 rows x 2 columns]

# %%
import pandas as pd
movie_df = pd.json_normalize(x)
movie_df
# Out:
#                                           description                director  \
# 0   Two imprisoned men bond over a number of years...        [Frank Darabont]
# 1   The aging patriarch of an organized crime dyna...  [Francis Ford Coppola]
# 2   When the menace known as the Joker wreaks havo...     [Christopher Nolan]
# 3   The early life and career of Vito Corleone in ...  [Francis Ford Coppola]
# 4   The jury in a New York City murder trial is fr...          [Sidney Lumet]
# ..                                                ...                     ...
# 95  The story of T.E. Lawrence, the English office...            [David Lean]
# 96  When the police in a German city are unable to...            [Fritz Lang]
# 97  After finding an old rifle, a young boy joins ...           [Elem Klimov]
# 98  A New York City advertising executive goes on ...      [Alfred Hitchcock]
# 99  A former San Francisco police detective juggle...      [Alfred Hitchcock]
#
#                             genre      id  \
# 0                         [Drama]    top1
# 1                  [Crime, Drama]    top2
# 2          [Action, Crime, Drama]    top3
# 3                  [Crime, Drama]    top4
# 4                  [Crime, Drama]    top5
# ..                            ...     ...
# 95  [Adventure, Biography, Drama]   top96
# 96     [Crime, Mystery, Thriller]   top97
# 97         [Drama, Thriller, War]   top98
# 98   [Action, Adventure, Mystery]   top99
# 99   [Mystery, Romance, Thriller]  top100
#
#                                                 image     imdbid  rank rating  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...  tt0111161     1    9.3
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...  tt0068646     2    9.2
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...  tt0468569     3    9.0
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...  tt0071562     4    9.0
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...  tt0050083     5    9.0
# ..                                                ...        ...   ...    ...
# 95  https://m.media-amazon.com/images/M/MV5BYWY5Zj...  tt0056172    96    8.3
# 96  https://m.media-amazon.com/images/M/MV5BODA4OD...  tt0022100    97    8.3
# 97  https://m.media-amazon.com/images/M/MV5BODM4Nj...  tt0091251    98    8.4
# 98  https://m.media-amazon.com/images/M/MV5BZDA3ND...  tt0053125    99    8.3
# 99  https://m.media-amazon.com/images/M/MV5BYTE4OD...  tt0052357   100    8.3
#
#                                             thumbnail  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                ...
# 95  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 96  https://m.media-amazon.com/images/M/MV5BODA4OD...
# 97  https://m.media-amazon.com/images/M/MV5BODM4Nj...
# 98  https://m.media-amazon.com/images/M/MV5BZDA3ND...
# 99  https://m.media-amazon.com/images/M/MV5BYTE4OD...
#
#                        title                                    trailer  \
# 0   The Shawshank Redemption  https://www.youtube.com/embed/NmzuHjWmXOc
# 1              The Godfather  https://www.youtube.com/embed/rqGJyUB1Q3s
# 2            The Dark Knight  https://www.youtube.com/embed/EXeTwQWrcwY
# 3      The Godfather Part II  https://www.youtube.com/embed/9O1Iy9od7-A
# 4               12 Angry Men  https://www.youtube.com/embed/TEN-2uTi2c0
# ..                       ...                                        ...
# 95        Lawrence of Arabia  https://www.youtube.com/embed/vOlRhGEhG7k
# 96                         M  https://www.youtube.com/embed/nsVproWjN6c
# 97              Come and See  https://www.youtube.com/embed/UHaSQU-4wss
# 98        North by Northwest  https://www.youtube.com/embed/Fx0QuZJVTFE
# 99                   Vertigo  https://www.youtube.com/embed/Z5jvQwwHQNY
#
#                                               writers  year
# 0   [Stephen King (based on the short novel "Rita ...  1994
# 1   [Mario Puzo (screenplay by), Francis Ford Copp...  1972
# 2   [Jonathan Nolan (screenplay), Christopher Nola...  2008
# 3   [Francis Ford Coppola (screenplay by), Mario P...  1974
# 4       [Reginald Rose (teleplay "Twelve Angry Men")]  1957
# ..                                                ...   ...
# 95  [Robert Bolt (screenplay by), Michael Wilson (...  1962
# 96  [Thea von Harbou (script), Fritz Lang (script)...  1931
# 97  [Ales Adamovich (story), Elem Klimov (screenpl...  1985
# 98                                    [Ernest Lehman]  1959
# 99  [Alec Coppel (screenplay by), Samuel A. Taylor...  1958
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Using a custom function with applymap() to pass a list of columns to convert column values of list type to string

# %%
def lst_to_str(df,cols):
    return df[cols].applymap(lambda x: ','.join([i for i in x]))

# %%
cols = ['director','genre','writers']
movie_df[[col+'_str' for col in cols]] = lst_to_str(movie_df,cols)

# %%
movie_df[['director','director_str','genre','genre_str','writers','writers_str']]
# Out:
#                   director          director_str  \
# 0         [Frank Darabont]        Frank Darabont
# 1   [Francis Ford Coppola]  Francis Ford Coppola
# 2      [Christopher Nolan]     Christopher Nolan
# 3   [Francis Ford Coppola]  Francis Ford Coppola
# 4           [Sidney Lumet]          Sidney Lumet
# ..                     ...                   ...
# 95            [David Lean]            David Lean
# 96            [Fritz Lang]            Fritz Lang
# 97           [Elem Klimov]           Elem Klimov
# 98      [Alfred Hitchcock]      Alfred Hitchcock
# 99      [Alfred Hitchcock]      Alfred Hitchcock
#
#                             genre                  genre_str  \
# 0                         [Drama]                      Drama
# 1                  [Crime, Drama]                Crime,Drama
# 2          [Action, Crime, Drama]         Action,Crime,Drama
# 3                  [Crime, Drama]                Crime,Drama
# 4                  [Crime, Drama]                Crime,Drama
# ..                            ...                        ...
# 95  [Adventure, Biography, Drama]  Adventure,Biography,Drama
# 96     [Crime, Mystery, Thriller]     Crime,Mystery,Thriller
# 97         [Drama, Thriller, War]         Drama,Thriller,War
# 98   [Action, Adventure, Mystery]   Action,Adventure,Mystery
# 99   [Mystery, Romance, Thriller]   Mystery,Romance,Thriller
#
#                                               writers  \
# 0   [Stephen King (based on the short novel "Rita ...
# 1   [Mario Puzo (screenplay by), Francis Ford Copp...
# 2   [Jonathan Nolan (screenplay), Christopher Nola...
# 3   [Francis Ford Coppola (screenplay by), Mario P...
# 4       [Reginald Rose (teleplay "Twelve Angry Men")]
# ..                                                ...
# 95  [Robert Bolt (screenplay by), Michael Wilson (...
# 96  [Thea von Harbou (script), Fritz Lang (script)...
# 97  [Ales Adamovich (story), Elem Klimov (screenpl...
# 98                                    [Ernest Lehman]
# 99  [Alec Coppel (screenplay by), Samuel A. Taylor...
#
#                                           writers_str
# 0   Stephen King (based on the short novel "Rita H...
# 1   Mario Puzo (screenplay by),Francis Ford Coppol...
# 2   Jonathan Nolan (screenplay),Christopher Nolan ...
# 3   Francis Ford Coppola (screenplay by),Mario Puz...
# 4         Reginald Rose (teleplay "Twelve Angry Men")
# ..                                                ...
# 95  Robert Bolt (screenplay by),Michael Wilson (sc...
# 96  Thea von Harbou (script),Fritz Lang (script),E...
# 97    Ales Adamovich (story),Elem Klimov (screenplay)
# 98                                      Ernest Lehman
# 99  Alec Coppel (screenplay by),Samuel A. Taylor (...
#
# [100 rows x 6 columns]
