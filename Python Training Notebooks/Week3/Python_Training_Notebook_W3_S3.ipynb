# %% [markdown]
# # Dataframes contd.
# ### Index and Filtering

# %%
auto_csv = r"C:\Users\ramananb\Downloads\Automobile.csv"

# %%
import pandas as pd
df = pd.read_csv(auto_csv)
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
"""
iloc - used to access a portion of a dataframe (rows & cols - using integers/positions)
Note: If there is no custom index set for rows, then by default the index is set from 0 
and the subsequent indices have values incremented by 1
"""
df.iloc[1:4, 3:6]   # accessing the rows through index 1 to 3 and columns through index 3 to 5
# Out:
#    displacement  horsepower  weight
# 1         350.0       165.0    3693
# 2         318.0       150.0    3436
# 3         304.0       150.0    3433

# %%
df.iloc[[3,6, 9, 11, 100], :] # accessing different row indices without having an actual range
# Out:
#                    name   mpg  cylinders  displacement  horsepower  weight  \
# 3         amc rebel sst  16.0          8         304.0       150.0    3433
# 6      chevrolet impala  14.0          8         454.0       220.0    4354
# 9    amc ambassador dpl  15.0          8         390.0       190.0    3850
# 11   plymouth 'cuda 340  14.0          8         340.0       160.0    3609
# 100       ford maverick  18.0          6         250.0        88.0    3021
#
#      acceleration  model_year origin
# 3            12.0          70    usa
# 6             9.0          70    usa
# 9             8.5          70    usa
# 11            8.0          70    usa
# 100          16.5          73    usa

# %%
df.iloc[[3,6, 9, 11, 100], [0, 2, 6]] # accessing different row and column indices without having an actual range
# Out:
#                    name  cylinders  acceleration
# 3         amc rebel sst          8          12.0
# 6      chevrolet impala          8           9.0
# 9    amc ambassador dpl          8           8.5
# 11   plymouth 'cuda 340          8           8.0
# 100       ford maverick          6          16.5

# %%
# Set custom index
df.set_index('name', inplace=True)  
# inplace=True will actually update the dataframe, without the argument df will not be impacted

# %%
df
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
# access the row indices with labels (ie., custom index values)
df.loc[['plymouth satellite','ford mustang gl','dodge rampage']]
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# name
# plymouth satellite  18.0          8         318.0       150.0    3436
# ford mustang gl     27.0          4         140.0        86.0    2790
# dodge rampage       32.0          4         135.0        84.0    2295
#
#                     acceleration  model_year origin
# name
# plymouth satellite          11.0          70    usa
# ford mustang gl             15.6          82    usa
# dodge rampage               11.6          82    usa

# %%
# accessing the rows and columns with actual labels
df.loc[['plymouth satellite','ford mustang gl','dodge rampage'], ['mpg','cylinders','horsepower']]
# Out:
#                      mpg  cylinders  horsepower
# name
# plymouth satellite  18.0          8       150.0
# ford mustang gl     27.0          4        86.0
# dodge rampage       32.0          4        84.0

# %%
# accessing row and column labels by having them in list variables
idx = ['plymouth satellite','ford mustang gl','dodge rampage','chevy s-10','vw pickup']
cols = ['mpg','cylinders','horsepower', 'origin']
df.loc[idx, cols]
# Out:
#                      mpg  cylinders  horsepower  origin
# name
# plymouth satellite  18.0          8       150.0     usa
# ford mustang gl     27.0          4        86.0     usa
# dodge rampage       32.0          4        84.0     usa
# chevy s-10          31.0          4        82.0     usa
# vw pickup           44.0          4        52.0  europe

# %%
df
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
# Column value to list
mpg_lst = df['mpg'].to_list()
mpg_lst
# Out:
# [18.0,
#  15.0,
#  18.0,
#  16.0,
#  17.0,
#  15.0,
#  14.0,
#  14.0,
#  14.0,
#  15.0,
#  15.0,
#  14.0,
#  15.0,
#  14.0,
#  24.0,
#  22.0,
#  18.0,
#  21.0,
#  27.0,
#  26.0,
#  25.0,
#  24.0,
#  25.0,
#  26.0,
#  21.0,
#  10.0,
#  10.0,
#  11.0,
#  9.0,
#  27.0,
#  28.0,
#  25.0,
#  25.0,
#  19.0,
#  16.0,
#  17.0,
#  19.0,
#  18.0,
#  14.0,
#  14.0,
#  14.0,
#  14.0,
#  12.0,
#  13.0,
#  13.0,
#  18.0,
#  22.0,
#  19.0,
#  18.0,
#  23.0,
#  28.0,
#  30.0,
#  30.0,
#  31.0,
#  35.0,
#  27.0,
#  26.0,
#  24.0,
#  25.0,
#  23.0,
#  20.0,
#  21.0,
#  13.0,
#  14.0,
#  15.0,
#  14.0,
#  17.0,
#  11.0,
#  13.0,
#  12.0,
#  13.0,
#  19.0,
#  15.0,
#  13.0,
#  13.0,
#  14.0,
#  18.0,
#  22.0,
#  21.0,
#  26.0,
#  22.0,
#  28.0,
#  23.0,
#  28.0,
#  27.0,
#  13.0,
#  14.0,
#  13.0,
#  14.0,
#  15.0,
#  12.0,
#  13.0,
#  13.0,
#  14.0,
#  13.0,
#  12.0,
#  13.0,
#  18.0,
#  16.0,
#  18.0,
#  18.0,
#  23.0,
#  26.0,
#  11.0,
#  12.0,
#  13.0,
#  12.0,
#  18.0,
#  20.0,
#  21.0,
#  22.0,
# ...

# %%
# Index values to list
idx_lst = list(df.index)  # can also use df.index.values
idx_lst
# Out:
# ['chevrolet chevelle malibu',
#  'buick skylark 320',
#  'plymouth satellite',
#  'amc rebel sst',
#  'ford torino',
#  'ford galaxie 500',
#  'chevrolet impala',
#  'plymouth fury iii',
#  'pontiac catalina',
#  'amc ambassador dpl',
#  'dodge challenger se',
#  "plymouth 'cuda 340",
#  'chevrolet monte carlo',
#  'buick estate wagon (sw)',
#  'toyota corona mark ii',
#  'plymouth duster',
#  'amc hornet',
#  'ford maverick',
#  'datsun pl510',
#  'volkswagen 1131 deluxe sedan',
#  'peugeot 504',
#  'audi 100 ls',
#  'saab 99e',
#  'bmw 2002',
#  'amc gremlin',
#  'ford f250',
#  'chevy c20',
#  'dodge d200',
#  'hi 1200d',
#  'datsun pl510',
#  'chevrolet vega 2300',
#  'toyota corona',
#  'ford pinto',
#  'amc gremlin',
#  'plymouth satellite custom',
#  'chevrolet chevelle malibu',
#  'ford torino 500',
#  'amc matador',
#  'chevrolet impala',
#  'pontiac catalina brougham',
#  'ford galaxie 500',
#  'plymouth fury iii',
#  'dodge monaco (sw)',
#  'ford country squire (sw)',
# ...

# %% [markdown]
# ### Filtering the Dataframe using conditions

# %%
# for example we want to filter the data where mpg >=18
df.loc[df['mpg']>=18]   # we can also store this sliced dataframe into another dataframe by assigning it to a variable
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# plymouth satellite         18.0          8         318.0       150.0    3436
# toyota corona mark ii      24.0          4         113.0        95.0    2372
# plymouth duster            22.0          6         198.0        95.0    2833
# amc hornet                 18.0          6         199.0        97.0    2774
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
df.loc[df['mpg']>=18, :]
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# plymouth satellite         18.0          8         318.0       150.0    3436
# toyota corona mark ii      24.0          4         113.0        95.0    2372
# plymouth duster            22.0          6         198.0        95.0    2833
# amc hornet                 18.0          6         199.0        97.0    2774
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
df.loc[df['mpg']>=18, ['mpg', 'weight', 'origin']]
# Out:
#                             mpg  weight  origin
# name
# chevrolet chevelle malibu  18.0    3504     usa
# plymouth satellite         18.0    3436     usa
# toyota corona mark ii      24.0    2372   japan
# plymouth duster            22.0    2833     usa
# amc hornet                 18.0    2774     usa
# ...                         ...     ...     ...
# ford mustang gl            27.0    2790     usa
# vw pickup                  44.0    2130  europe
# dodge rampage              32.0    2295     usa
# ford ranger                28.0    2625     usa
# chevy s-10                 31.0    2720     usa
#
# [291 rows x 3 columns]

# %% [markdown]
# ### Dataframe filter with multiple conditions using logical operators

# %%
# mpg >=18 and origin=='usa'
df.loc[(df['mpg']>=18)&(df['origin']=='usa')]
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# plymouth satellite         18.0          8         318.0       150.0    3436
# plymouth duster            22.0          6         198.0        95.0    2833
# amc hornet                 18.0          6         199.0        97.0    2774
# ford maverick              21.0          6         200.0        85.0    2587
# ...                         ...        ...           ...         ...     ...
# chevrolet camaro           27.0          4         151.0        90.0    2950
# ford mustang gl            27.0          4         140.0        86.0    2790
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
# mpg >=18 or origin=='usa'
df.loc[(df['mpg']>=18)|(df['origin']=='usa')]
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %% [markdown]
# ### we can also access the filters by assigning them to variables

# %%
filter1 = ((df['mpg']>=18)|(df['origin']=='usa'))
df.loc[filter1]
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
# Resetting the index
df.reset_index(inplace=True)

# %%
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %% [markdown]
# ### Multi-indexing

# %%
df.set_index(['name','mpg'],inplace=True)

# %%
df
# Out:
#                                 cylinders  displacement  horsepower  weight  \
# name                      mpg
# chevrolet chevelle malibu 18.0          8         307.0       130.0    3504
# buick skylark 320         15.0          8         350.0       165.0    3693
# plymouth satellite        18.0          8         318.0       150.0    3436
# amc rebel sst             16.0          8         304.0       150.0    3433
# ford torino               17.0          8         302.0       140.0    3449
# ...                                   ...           ...         ...     ...
# ford mustang gl           27.0          4         140.0        86.0    2790
# vw pickup                 44.0          4          97.0        52.0    2130
# dodge rampage             32.0          4         135.0        84.0    2295
# ford ranger               28.0          4         120.0        79.0    2625
# chevy s-10                31.0          4         119.0        82.0    2720
#
# ...

# %% [markdown]
# ### Filtering based on level 0 index

# %%
df.loc['ford maverick']
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model_year  \
# mpg
# 21.0          6         200.0        85.0    2587          16.0          70
# 18.0          6         250.0        88.0    3021          16.5          73
# 21.0          6         200.0         NaN    2875          17.0          74
# 15.0          6         250.0        72.0    3158          19.5          75
# 24.0          6         200.0        81.0    3012          17.6          76
#
#      origin
# mpg
# 21.0    usa
# 18.0    usa
# 21.0    usa
# 15.0    usa
# 24.0    usa

# %%
df.loc['ford maverick',:]
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model_year  \
# mpg
# 21.0          6         200.0        85.0    2587          16.0          70
# 18.0          6         250.0        88.0    3021          16.5          73
# 21.0          6         200.0         NaN    2875          17.0          74
# 15.0          6         250.0        72.0    3158          19.5          75
# 24.0          6         200.0        81.0    3012          17.6          76
#
#      origin
# mpg
# 21.0    usa
# 18.0    usa
# 21.0    usa
# 15.0    usa
# 24.0    usa

# %%
df.loc[['ford maverick','chevy s-10']]
# Out:
#                     cylinders  displacement  horsepower  weight  acceleration  \
# name          mpg
# ford maverick 21.0          6         200.0        85.0    2587          16.0
#               18.0          6         250.0        88.0    3021          16.5
#               21.0          6         200.0         NaN    2875          17.0
#               15.0          6         250.0        72.0    3158          19.5
#               24.0          6         200.0        81.0    3012          17.6
# chevy s-10    31.0          4         119.0        82.0    2720          19.4
#
#                     model_year origin
# name          mpg
# ford maverick 21.0          70    usa
#               18.0          73    usa
#               21.0          74    usa
#               15.0          75    usa
#               24.0          76    usa
# chevy s-10    31.0          82    usa

# %%
list(df.index)  
# The output below is a list of tuples. Each tuple corresponds to a multi-index grouped together
# Out:
# [('chevrolet chevelle malibu', 18.0),
#  ('buick skylark 320', 15.0),
#  ('plymouth satellite', 18.0),
#  ('amc rebel sst', 16.0),
#  ('ford torino', 17.0),
#  ('ford galaxie 500', 15.0),
#  ('chevrolet impala', 14.0),
#  ('plymouth fury iii', 14.0),
#  ('pontiac catalina', 14.0),
#  ('amc ambassador dpl', 15.0),
#  ('dodge challenger se', 15.0),
#  ("plymouth 'cuda 340", 14.0),
#  ('chevrolet monte carlo', 15.0),
#  ('buick estate wagon (sw)', 14.0),
#  ('toyota corona mark ii', 24.0),
#  ('plymouth duster', 22.0),
#  ('amc hornet', 18.0),
#  ('ford maverick', 21.0),
#  ('datsun pl510', 27.0),
#  ('volkswagen 1131 deluxe sedan', 26.0),
#  ('peugeot 504', 25.0),
#  ('audi 100 ls', 24.0),
#  ('saab 99e', 25.0),
#  ('bmw 2002', 26.0),
#  ('amc gremlin', 21.0),
#  ('ford f250', 10.0),
#  ('chevy c20', 10.0),
#  ('dodge d200', 11.0),
#  ('hi 1200d', 9.0),
#  ('datsun pl510', 27.0),
#  ('chevrolet vega 2300', 28.0),
#  ('toyota corona', 25.0),
#  ('ford pinto', 25.0),
# ...

# %% [markdown]
# ### Filtering based on multi-index
# we use list of tuples

# %%
df.loc[[('chevrolet impala', 14.0),('amc gremlin', 19.0)]]
# Out:
#                        cylinders  displacement  horsepower  weight  \
# name             mpg
# chevrolet impala 14.0          8         454.0       220.0    4354
#                  14.0          8         350.0       165.0    4209
# amc gremlin      19.0          6         232.0       100.0    2634
#
#                        acceleration  model_year origin
# name             mpg
# chevrolet impala 14.0           9.0          70    usa
#                  14.0          12.0          71    usa
# amc gremlin      19.0          13.0          71    usa

# %%
df.loc[['chevrolet impala','amc gremlin']]
# Out:
#                        cylinders  displacement  horsepower  weight  \
# name             mpg
# chevrolet impala 14.0          8         454.0       220.0    4354
#                  14.0          8         350.0       165.0    4209
#                  13.0          8         350.0       165.0    4274
#                  11.0          8         400.0       150.0    4997
# amc gremlin      21.0          6         199.0        90.0    2648
#                  19.0          6         232.0       100.0    2634
#                  18.0          6         232.0       100.0    2789
#                  20.0          6         232.0       100.0    2914
#
#                        acceleration  model_year origin
# name             mpg
# chevrolet impala 14.0           9.0          70    usa
#                  14.0          12.0          71    usa
#                  13.0          12.0          72    usa
#                  11.0          14.0          73    usa
# ...

# %%
df
# Out:
#                                 cylinders  displacement  horsepower  weight  \
# name                      mpg
# chevrolet chevelle malibu 18.0          8         307.0       130.0    3504
# buick skylark 320         15.0          8         350.0       165.0    3693
# plymouth satellite        18.0          8         318.0       150.0    3436
# amc rebel sst             16.0          8         304.0       150.0    3433
# ford torino               17.0          8         302.0       140.0    3449
# ...                                   ...           ...         ...     ...
# ford mustang gl           27.0          4         140.0        86.0    2790
# vw pickup                 44.0          4          97.0        52.0    2130
# dodge rampage             32.0          4         135.0        84.0    2295
# ford ranger               28.0          4         120.0        79.0    2625
# chevy s-10                31.0          4         119.0        82.0    2720
#
# ...

# %% [markdown]
# ### Filtering based on multi-index but skipping level 0 index and using only level 1 index

# %%
df[df.index.isin([14], level=1)]  
# Note: 14 is not a position/index but index value for mpg
# Out:
#                                      cylinders  displacement  horsepower  \
# name                           mpg
# chevrolet impala               14.0          8         454.0       220.0
# plymouth fury iii              14.0          8         440.0       215.0
# pontiac catalina               14.0          8         455.0       225.0
# plymouth 'cuda 340             14.0          8         340.0       160.0
# buick estate wagon (sw)        14.0          8         455.0       225.0
# chevrolet impala               14.0          8         350.0       165.0
# pontiac catalina brougham      14.0          8         400.0       175.0
# ford galaxie 500               14.0          8         351.0       153.0
# plymouth fury iii              14.0          8         318.0       150.0
# pontiac catalina               14.0          8         400.0       175.0
# ford galaxie 500               14.0          8         351.0       153.0
# ...

# %%
df[df.index.isin([14, 17, 32], level=1)]  # we can also pass list of index values
# Out:
#                                      cylinders  displacement  horsepower  \
# name                           mpg
# ford torino                    17.0          8         302.0       140.0
# chevrolet impala               14.0          8         454.0       220.0
# plymouth fury iii              14.0          8         440.0       215.0
# pontiac catalina               14.0          8         455.0       225.0
# plymouth 'cuda 340             14.0          8         340.0       160.0
# buick estate wagon (sw)        14.0          8         455.0       225.0
# chevrolet chevelle malibu      17.0          6         250.0       100.0
# chevrolet impala               14.0          8         350.0       165.0
# pontiac catalina brougham      14.0          8         400.0       175.0
# ford galaxie 500               14.0          8         351.0       153.0
# plymouth fury iii              14.0          8         318.0       150.0
# ...

# %%
df[df.index.isin([14.0, 17, 32], level=1)]
# Out:
#                                      cylinders  displacement  horsepower  \
# name                           mpg
# ford torino                    17.0          8         302.0       140.0
# chevrolet impala               14.0          8         454.0       220.0
# plymouth fury iii              14.0          8         440.0       215.0
# pontiac catalina               14.0          8         455.0       225.0
# plymouth 'cuda 340             14.0          8         340.0       160.0
# buick estate wagon (sw)        14.0          8         455.0       225.0
# chevrolet chevelle malibu      17.0          6         250.0       100.0
# chevrolet impala               14.0          8         350.0       165.0
# pontiac catalina brougham      14.0          8         400.0       175.0
# ford galaxie 500               14.0          8         351.0       153.0
# plymouth fury iii              14.0          8         318.0       150.0
# ...

# %%
mpg_lst = [14.0, 17, 32]
df[df.index.isin(mpg_lst, level=1)]   # we can also pass a list variable
# Out:
#                                      cylinders  displacement  horsepower  \
# name                           mpg
# ford torino                    17.0          8         302.0       140.0
# chevrolet impala               14.0          8         454.0       220.0
# plymouth fury iii              14.0          8         440.0       215.0
# pontiac catalina               14.0          8         455.0       225.0
# plymouth 'cuda 340             14.0          8         340.0       160.0
# buick estate wagon (sw)        14.0          8         455.0       225.0
# chevrolet chevelle malibu      17.0          6         250.0       100.0
# chevrolet impala               14.0          8         350.0       165.0
# pontiac catalina brougham      14.0          8         400.0       175.0
# ford galaxie 500               14.0          8         351.0       153.0
# plymouth fury iii              14.0          8         318.0       150.0
# ...

# %% [markdown]
# ### Another way of filtering based on multi-index but skipping level 0 index and using only level 1 index

# %%
df.loc[(slice(None),14),:] 
# in this method we have to explicitly specify even if we want all the columns unlike the previous methods
# Out:
#                                      cylinders  displacement  horsepower  \
# name                           mpg
# chevrolet impala               14.0          8         454.0       220.0
# plymouth fury iii              14.0          8         440.0       215.0
# pontiac catalina               14.0          8         455.0       225.0
# plymouth 'cuda 340             14.0          8         340.0       160.0
# buick estate wagon (sw)        14.0          8         455.0       225.0
# chevrolet impala               14.0          8         350.0       165.0
# pontiac catalina brougham      14.0          8         400.0       175.0
# ford galaxie 500               14.0          8         351.0       153.0
# plymouth fury iii              14.0          8         318.0       150.0
# pontiac catalina               14.0          8         400.0       175.0
# ford galaxie 500               14.0          8         351.0       153.0
# ...
